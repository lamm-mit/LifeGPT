# %%
print("Training LifeGPT Multi Grid")

import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'
import random
import numpy as np
import torch
import torch.optim as optim
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
import pandas as pd
import time
from x_transformers import TransformerWrapper, Decoder
from x_transformers.autoregressive_wrapper import AutoregressiveWrapper
import datetime
from IPython.display import display, HTML
from tqdm import tqdm
import typing
import matplotlib.pyplot as plt
import csv

# =============================================================================
#                           Helper Functions / Setup
# =============================================================================

def empty_cuda_cache():
    """Clears the CUDA cache."""
    torch.cuda.empty_cache()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
print("Torch version:", torch.__version__)
empty_cuda_cache()

# =============================================================================
#                            Data Loading
# =============================================================================

data_path = "datasets\\"
train_file = data_path + "conway_multi_grid_train_20250107_180038.csv"
val_file   = data_path + "conway_multi_grid_val_20250107_181530.csv"
test_file  = data_path + "conway_multi_grid_test_20250107_181732.csv"

df_train = pd.read_csv(train_file)
df_val   = pd.read_csv(val_file)
df_test  = pd.read_csv(test_file)

TRAIN_SIZE = 10000
TEST_SIZE  = 1000

start_char = "@"
end_char   = "$"
mask_char  = ["_"]

def generate_data(df, future_steps):
    """Generate text-based sequences from DataFrame columns."""
    X_data = []
    for i in range(len(df['State 1'])):
        future_state_col = f"State {future_steps}"
        if future_state_col in df.columns:
            str_ = f"{start_char}PredictNextState<{df['State 1'][i]}> [{df[future_state_col][i]}]{end_char}"
            X_data.append(str_)
    return X_data

future_steps_list = [2]
X_data_train = {steps: generate_data(df_train, steps) for steps in future_steps_list}
X_data_val   = {steps: generate_data(df_val,   steps) for steps in future_steps_list}
X_data_test  = {steps: generate_data(df_test,  steps) for steps in future_steps_list}

print("Sample from X_data_test[2]:", X_data_test[2][0])
print("First character of sample:", X_data_test[2][0][0])

for steps in future_steps_list:
    print(f"Train set for {steps} steps: {len(X_data_train[steps])} sequences")
    print(f"Val   set for {steps} steps: {len(X_data_val[steps])} sequences")

max_length = max(len(seq) for steps in future_steps_list for seq in X_data_train[steps])
print("Max sequence length:", max_length)

# =============================================================================
#                            Tokenizer
# =============================================================================

num_words = 256

class Tokenizer:
    def __init__(self, n_pad: int, device: torch.device, pad_byte: int = 0):
        self.n_pad = n_pad
        self.device = device
        self.pad_byte = pad_byte

    def tokenize_str(self, sentence: str, encoding="utf8", do_padding=True):
        base = list(bytes(sentence, encoding))
        if do_padding:
            if len(base) < self.n_pad:
                base.extend([self.pad_byte] * (self.n_pad - len(base)))
            assert len(base) == self.n_pad, f"n_pad is too small. Need at least {len(base)}."
        tensor = torch.Tensor(base)
        return tensor.long().to(self.device)

    def texts_to_sequences(self, texts: typing.List[str], encoding="utf8", do_padding=True):
        sentences = [self.tokenize_str(sentence, do_padding=do_padding).unsqueeze(0) for sentence in texts]
        return torch.cat(sentences, dim=0).to(self.device)

    @staticmethod
    def prepare_texts(document: str) -> typing.List[str]:
        return list(filter(lambda x: len(x) != 0, document.split("\n")))

    def sequences_to_texts(self, texts: torch.Tensor, encoding="utf8"):
        out = []
        for seq in texts:
            chars = []
            i = 0
            while i < len(seq) and seq[i] != 0:
                chars.append(int(seq[i]))
                i += 1
            try:
                out.append(bytes(chars).decode(encoding))
            except:
                pass
        return out

tokenizer_X = Tokenizer(max_length, device)

def tokenize_data(data, tokenizer):
    tokenized_data = tokenizer.texts_to_sequences(data)
    print("Example tokenized data:", tokenized_data[0])
    return tokenized_data

X_data_train_tokenized = {steps: tokenize_data(X_data_train[steps], tokenizer_X) for steps in future_steps_list}
X_data_val_tokenized   = {steps: tokenize_data(X_data_val[steps],   tokenizer_X) for steps in future_steps_list}

def tokenize_special_char(char, tokenizer):
    token = tokenizer.texts_to_sequences([char])
    token_value = token[0][0].cpu().numpy()
    print(f"'{char}' token:", token_value)
    return token_value

start_char_token = tokenize_special_char(start_char, tokenizer_X)
end_char_token   = tokenize_special_char(end_char,   tokenizer_X)
mask_token       = tokenize_special_char(mask_char[0], tokenizer_X)
print("Mask token:", mask_token)

def remove_start_end_token(string_input, start='@', end='$'):
    return string_input.replace(start, "").replace(end, "")

def remove_start_end_token_first(string_input, start='@', end='$'):
    i = string_input.find(start)
    j = string_input.find(end)
    return string_input[i+1:j]

def extract_task(string_input, end_task_token=')'):
    j = string_input.find(end_task_token)
    return string_input[:j+1]

def extract_start_and_end(string_input, start_token='[', end_token=']'):
    i = string_input.find(start_token)
    j = string_input.find(end_token)
    return string_input[i+1:j]

def reverse_tokenize(tokenizer_X, X_data, X_norm_factor=1):
    X_data_tokenized_reversed = tokenizer_X.sequences_to_texts((X_data * X_norm_factor).int())
    return [i for i in X_data_tokenized_reversed]

# Quick test of tokenization
aa = reverse_tokenize(tokenizer_X, X_data_train_tokenized[2][1:2])
bb = X_data_train[2][1:2]
if aa == bb:
    print("Tokenization and reverse tokenization are consistent.")
else:
    print("Inconsistent behavior detected.")

print("extract_task example:", extract_task(remove_start_end_token_first(X_data_train[2][1]), end_task_token='>'))
print("Original text:", X_data_train[2][1])
print("extract_start_and_end(<,>):", extract_start_and_end(X_data_train[2][1], start_token='<', end_token='>'))
print("extract_start_and_end([,]):", extract_start_and_end(X_data_train[2][1], start_token='[', end_token=']'))
print("Reverse token val data sample:", reverse_tokenize(tokenizer_X, X_data_val_tokenized[2][:1]))
print("Original val data sample:", X_data_val[2][1])

# =============================================================================
#                            Model Definition
# =============================================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device re-checked:", device)

def empty_cuda_cache():
    """Clears the CUDA cache."""
    torch.cuda.empty_cache()

def get_model(max_length, num_words, model_name,
              dim=256, depth=12, heads=8, attn_dim_head=64,
              rot_pos=True, attn_flash=True,
              masking=True, mask_prob=0.15):
    empty_cuda_cache()

    model = TransformerWrapper(
        num_tokens=num_words,
        max_seq_len=max_length,
        attn_layers=Decoder(
            dim=dim,
            depth=depth,
            heads=heads,
            attn_dim_head=attn_dim_head,
            rotary_pos_emb=rot_pos,
            attn_flash=attn_flash
        )
    )

    if masking:
        model = AutoregressiveWrapper(model, mask_prob=mask_prob)
        print(f"Model created: rot pos={rot_pos}, attn_flash={attn_flash}, masking={masking}")
    else:
        model = AutoregressiveWrapper(model)
        print(f"Model created: rot pos={rot_pos}, attn_flash={attn_flash}, masking={masking}")

    model.cuda()

    model_creation_time = datetime.datetime.now()
    model_creation_time_str = model_creation_time.strftime("%Y-%m-%d_%H-%M-%S")
    print(f'Model "{model_name}" Created @ {model_creation_time_str} Eastern Time')

    num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"Model has {num_params} trainable parameters")

    # Use the small-snippet style path creation
    model_dir = os.path.join(os.getcwd(), "model_parameters", f"{model_name}_{model_creation_time_str}")
    print("DEBUG: Attempting to create model_dir:", model_dir)
    os.makedirs(model_dir, exist_ok=True)
    print("DEBUG: Directory exists after creation?", os.path.exists(model_dir))

    model_info_file = os.path.join(model_dir, f"{model_name}_info.txt")
    print("DEBUG: model_info_file:", model_info_file)

    with open(model_info_file, "w") as f:
        f.write(f"Model Name: {model_name}\n")
        f.write(f"Model Created @ {model_creation_time_str} Eastern Time\n")
        f.write(f"Number of trainable parameters: {num_params}\n")
        f.write(f"Model Architecture:\n{model}\n")
        f.write("Model Parameters:\n")
        f.write(f"num_tokens: {num_words}\n")
        f.write(f"max_seq_len: {max_length}\n")
        f.write(f"dim: {dim}\n")
        f.write(f"depth: {depth}\n")
        f.write(f"heads: {heads}\n")
        f.write(f"attn_dim_head: {attn_dim_head}\n")
        f.write(f"rotary_pos_emb: {rot_pos}\n")
        f.write(f"attn_flash: {attn_flash}\n\n")
        f.write("Note: Jan-08-This model is looking at the effects of varying grid sizes on generalization.")

    return model, model_dir

model_name = "01_07_2025_Conway_Multi_Grid"
rot_pos = True
model, model_dir = get_model(max_length, num_words, model_name, rot_pos=rot_pos, masking=True, mask_prob=0.15)

empty_cuda_cache()
print("CUDA cache cleared.")

LEARNING_RATE = 1e-4
optim = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# =============================================================================
#                          DataLoader / Datasets
# =============================================================================

def cycle(loader):
    """Yields batches from loader in an infinite cycle."""
    while True:
        for data in loader:
            yield data

class RegressionDataset(Dataset):
    def __init__(self, X_data):
        self.X_data = X_data
    
    def __getitem__(self, index):
        return self.X_data[index]
    
    def __len__(self):
        return len(self.X_data)

NUM_EPOCHS                = 50
SAVE_EPOCH                = 2
VALIDATE_EVERY            = 5
GENERATE_EVERY            = 10
GRADIENT_ACCUMULATE_EVERY = 5
MEASURE_ACC_EVERY         = 1000
BATCH_SIZE                = 5

steps = future_steps_list[0]
GENERATE_LENGTH = max_length - len(extract_task(X_data_train[steps][0], end_task_token='>'))
print("GENERATE_LENGTH =", GENERATE_LENGTH)
print(f"Predicting jump from State 1 to State {steps}")

train_dataset = RegressionDataset(X_data_train_tokenized[steps])
val_dataset   = RegressionDataset(X_data_val_tokenized[steps])
train_loader  = cycle(DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True))
val_loader    = cycle(DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=True, drop_last=True))

train_sample = next(train_loader)
val_sample   = next(val_loader)
print("Train batch shape:", train_sample.shape)
print("Validation batch shape:", val_sample.shape)

torch.cuda.empty_cache()

display(HTML("<style>.output_result { max-height:10000px; }</style>"))

# =============================================================================
#                           Generation and Accuracy
# =============================================================================

def generate_sample():
    model.eval()
    inp_str = extract_task(random.choice(X_data_val), end_task_token=">")
    inp = torch.Tensor(tokenizer_X.texts_to_sequences(inp_str, do_padding=False)).to(device)
    inp = inp.transpose(0, 1).long()
    prime = reverse_tokenize(tokenizer_X, inp[:1])[0]
    sample = model.generate(prompts=inp, seq_len=GENERATE_LENGTH, cache_kv=True)
    try:
        output_str = reverse_tokenize(tokenizer_X, sample[:1])
    except:
        output_str = ["non utf token found"]
    return output_str

def count_mismatches(ground_truth, pred):
    mismatches = sum(1 for gt, p in zip(ground_truth, pred) if gt != p)
    accuracy = 1 - mismatches / len(ground_truth)
    return mismatches, accuracy

# =============================================================================
#                         CSV Logging for Loss / Accuracy
# =============================================================================

csv_file_path = os.path.join(model_dir, "loss_data.csv")
print("DEBUG: Writing CSV to:", csv_file_path)
with open(csv_file_path, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["epoch", "batch_within_epoch", "batch_overall", "train_loss", "val_loss", "accuracy", "elapsed_time"])

train_losses         = []
val_losses           = []
batches              = []
accuracies           = []
accuracies_batches   = []
epoch_list           = []
batch_overall        = []

total_batches = NUM_EPOCHS * int(TRAIN_SIZE / BATCH_SIZE)
overall_batch_counter = 0
accuracy = 0
start_time = time.time()

# =============================================================================
#                              Training Loop
# =============================================================================

for epoch in range(NUM_EPOCHS):
    num_batches = int(TRAIN_SIZE / BATCH_SIZE)
    print(f"Epoch {epoch+1}/{NUM_EPOCHS}")
    epoch_start_time = time.time()

    for i in range(num_batches):
        model.train()
        loss = model(next(train_loader))
        loss.backward()
        
        if (i + 1) % GRADIENT_ACCUMULATE_EVERY == 0:
            torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
            optim.step()
            optim.zero_grad()

        model.eval()
        with torch.no_grad():
            val_loss = model(next(val_loader)).item()

        train_losses.append(loss.item())
        val_losses.append(val_loss)
        batches.append(overall_batch_counter)
        batch_overall.append(overall_batch_counter)

        if (i + 1) % MEASURE_ACC_EVERY == 0:
            valid_output_found = False
            attempt_count = 0
            max_attempts = 1
            accuracy_list = []
            while len(accuracy_list) < 10 and attempt_count < max_attempts:
                inp_seq = X_data_test[2][len(accuracy_list)]
                inp_str = extract_task(inp_seq, end_task_token=">")
                inp = torch.Tensor(tokenizer_X.texts_to_sequences(inp_str, do_padding=False)).to(device)
                inp = inp.transpose(0, 1).long()
                with torch.no_grad():
                    sample = model.generate(prompts=inp, seq_len=GENERATE_LENGTH, cache_kv=True)
                try:
                    output_str = reverse_tokenize(tokenizer_X, sample[:1])
                    pred         = extract_start_and_end(output_str[0], start_token="[", end_token="]")
                    ground_truth = extract_start_and_end(inp_seq,       start_token="[", end_token="]")
                    _, acc = count_mismatches(ground_truth=ground_truth, pred=pred)
                    accuracy_list.append(acc)
                    valid_output_found = True
                except Exception as e:
                    print("Error decoding output:", e)
                    attempt_count += 1
            
            if valid_output_found and len(accuracy_list) > 0:
                accuracy = np.mean(accuracy_list)
            else:
                accuracy = 0

            accuracies.append(accuracy)
            accuracies_batches.append(overall_batch_counter)

        elapsed_time = time.time() - start_time
        with open(csv_file_path, mode="a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([epoch, i, overall_batch_counter, loss.item(), val_loss, accuracy, elapsed_time])

        if (i + 1) % VALIDATE_EVERY == 0:
            print(f"Batch {i+1}/{num_batches}, Train Loss: {loss.item():.4f}, Val Loss: {val_loss:.4f}, Accuracy: {accuracy:.4f}")

        overall_batch_counter += 1

    if (epoch + 1) % SAVE_EPOCH == 0:
        model_save_path = os.path.join(model_dir, f"LifeGPT_multi_grid_epoch_{epoch+1}.pt")
        torch.save(model.state_dict(), model_save_path)
        print(f"Model saved at epoch {epoch+1}, file: {model_save_path}")

    epoch_end_time = time.time()
    print(f"Epoch {epoch+1} time: {epoch_end_time - epoch_start_time:.2f} seconds")
# Out:
# Training LifeGPT Multi Grid
# Device: cuda
# Torch version: 2.2.2
# Sample from X_data_test[2]: @PredictNextState<> []$
# First character of sample: @
# Train set for 2 steps: 10000 sequences
# Val   set for 2 steps: 1000 sequences
# Max sequence length: 535
# Example tokenized data: tensor([ 64,  80, 114, 101, 100, 105,  99, 116,  78, 101, 120, 116,  83, 116,
#          97, 116, 101,  60,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  62,  32,  91,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  93,  36], device='cuda:0')
# Example tokenized data: tensor([ 64,  80, 114, 101, 100, 105,  99, 116,  78, 101, 120, 116,  83, 116,
#          97, 116, 101,  60,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  62,  32,  91,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,  48,
#          48,  93,  36], device='cuda:0')
# '@' token: 64
# '$' token: 36
# '_' token: 95
# Mask token: 95
# Tokenization and reverse tokenization are consistent.
# extract_task example: PredictNextState<>
# Original text: @PredictNextState<> []$
# extract_start_and_end(<,>): 
# extract_start_and_end([,]): 
# Reverse token val data sample: ['@PredictNextState<> []$']
# Original val data sample: @PredictNextState<> []$
# Device re-checked: cuda
# Model created: rot pos=True, attn_flash=True, masking=True
# Model "01_07_2025_Conway_Multi_Grid" Created @ 2025-01-08_13-09-21 Eastern Time
# Model has 12735744 trainable parameters
# DEBUG: Attempting to create model_dir: c:\Users\jaime\ML_Playground_1\LifeGPT\Multi_Grid\model_parameters\01_07_2025_Conway_Multi_Grid_2025-01-08_13-09-21
# DEBUG: Directory exists after creation? True
# DEBUG: model_info_file: c:\Users\jaime\ML_Playground_1\LifeGPT\Multi_Grid\model_parameters\01_07_2025_Conway_Multi_Grid_2025-01-08_13-09-21\01_07_2025_Conway_Multi_Grid_info.txt
# CUDA cache cleared.
# GENERATE_LENGTH = 260
# Predicting jump from State 1 to State 2
# Train batch shape: torch.Size([5, 535])
# Validation batch shape: torch.Size([5, 535])
# <style>.output_result { max-height:10000px; }</style>
# DEBUG: Writing CSV to: c:\Users\jaime\ML_Playground_1\LifeGPT\Multi_Grid\model_parameters\01_07_2025_Conway_Multi_Grid_2025-01-08_13-09-21\loss_data.csv
# Epoch 1/50
# Batch 5/2000, Train Loss: 5.5755, Val Loss: 2.8812, Accuracy: 0.0000
# Batch 10/2000, Train Loss: 2.8896, Val Loss: 1.2987, Accuracy: 0.0000
# Batch 15/2000, Train Loss: 2.0007, Val Loss: 1.2733, Accuracy: 0.0000
# Batch 20/2000, Train Loss: 1.3060, Val Loss: 0.9320, Accuracy: 0.0000
# Batch 25/2000, Train Loss: 0.8225, Val Loss: 0.9456, Accuracy: 0.0000
# Batch 30/2000, Train Loss: 0.6265, Val Loss: 0.6486, Accuracy: 0.0000
# Batch 35/2000, Train Loss: 0.8255, Val Loss: 0.6667, Accuracy: 0.0000
# Batch 40/2000, Train Loss: 0.6604, Val Loss: 0.8544, Accuracy: 0.0000
# Batch 45/2000, Train Loss: 0.6476, Val Loss: 0.7168, Accuracy: 0.0000
# Batch 50/2000, Train Loss: 0.7845, Val Loss: 0.7942, Accuracy: 0.0000
# Batch 55/2000, Train Loss: 0.6473, Val Loss: 0.4893, Accuracy: 0.0000
# Batch 60/2000, Train Loss: 0.6957, Val Loss: 0.4666, Accuracy: 0.0000
# Batch 65/2000, Train Loss: 0.4468, Val Loss: 0.3623, Accuracy: 0.0000
# Batch 70/2000, Train Loss: 0.5307, Val Loss: 0.5881, Accuracy: 0.0000
# Batch 75/2000, Train Loss: 0.6210, Val Loss: 0.3177, Accuracy: 0.0000
# Batch 80/2000, Train Loss: 0.5416, Val Loss: 0.4585, Accuracy: 0.0000
# Batch 85/2000, Train Loss: 0.4433, Val Loss: 0.4448, Accuracy: 0.0000
# Batch 90/2000, Train Loss: 0.4382, Val Loss: 0.4213, Accuracy: 0.0000
# Batch 95/2000, Train Loss: 0.4325, Val Loss: 0.2758, Accuracy: 0.0000
# Batch 100/2000, Train Loss: 0.5263, Val Loss: 0.3073, Accuracy: 0.0000
# Batch 105/2000, Train Loss: 0.2369, Val Loss: 0.2988, Accuracy: 0.0000
# Batch 110/2000, Train Loss: 0.3003, Val Loss: 0.3558, Accuracy: 0.0000
# Batch 115/2000, Train Loss: 0.4253, Val Loss: 0.4222, Accuracy: 0.0000
# Batch 120/2000, Train Loss: 0.4005, Val Loss: 0.3862, Accuracy: 0.0000
# Batch 125/2000, Train Loss: 0.3828, Val Loss: 0.5184, Accuracy: 0.0000
# Batch 130/2000, Train Loss: 0.4951, Val Loss: 0.2418, Accuracy: 0.0000
# Batch 135/2000, Train Loss: 0.2455, Val Loss: 0.3443, Accuracy: 0.0000
# Batch 140/2000, Train Loss: 0.2884, Val Loss: 0.4442, Accuracy: 0.0000
# Batch 145/2000, Train Loss: 0.3930, Val Loss: 0.2472, Accuracy: 0.0000
# Batch 150/2000, Train Loss: 0.2957, Val Loss: 0.2689, Accuracy: 0.0000
# Batch 155/2000, Train Loss: 0.1854, Val Loss: 0.3931, Accuracy: 0.0000
# Batch 160/2000, Train Loss: 0.2561, Val Loss: 0.3594, Accuracy: 0.0000
# Batch 165/2000, Train Loss: 0.2372, Val Loss: 0.2264, Accuracy: 0.0000
# Batch 170/2000, Train Loss: 0.3174, Val Loss: 0.2566, Accuracy: 0.0000
# Batch 175/2000, Train Loss: 0.2528, Val Loss: 0.1644, Accuracy: 0.0000
# Batch 180/2000, Train Loss: 0.3366, Val Loss: 0.1639, Accuracy: 0.0000
# Batch 185/2000, Train Loss: 0.2055, Val Loss: 0.3204, Accuracy: 0.0000
# Batch 190/2000, Train Loss: 0.2294, Val Loss: 0.4587, Accuracy: 0.0000
# Batch 195/2000, Train Loss: 0.2815, Val Loss: 0.2132, Accuracy: 0.0000
# Batch 200/2000, Train Loss: 0.1738, Val Loss: 0.4498, Accuracy: 0.0000
# Batch 205/2000, Train Loss: 0.2417, Val Loss: 0.1546, Accuracy: 0.0000
# Batch 210/2000, Train Loss: 0.1171, Val Loss: 0.2500, Accuracy: 0.0000
# Batch 215/2000, Train Loss: 0.1394, Val Loss: 0.4097, Accuracy: 0.0000
# Batch 220/2000, Train Loss: 0.2357, Val Loss: 0.1766, Accuracy: 0.0000
# Batch 225/2000, Train Loss: 0.2377, Val Loss: 0.1296, Accuracy: 0.0000
# Batch 230/2000, Train Loss: 0.1598, Val Loss: 0.0936, Accuracy: 0.0000
# Batch 235/2000, Train Loss: 0.3240, Val Loss: 0.2168, Accuracy: 0.0000
# Batch 240/2000, Train Loss: 0.0931, Val Loss: 0.3604, Accuracy: 0.0000
# Batch 245/2000, Train Loss: 0.2587, Val Loss: 0.1208, Accuracy: 0.0000
# Batch 250/2000, Train Loss: 0.2021, Val Loss: 0.1219, Accuracy: 0.0000
# Batch 255/2000, Train Loss: 0.2410, Val Loss: 0.3028, Accuracy: 0.0000
# Batch 260/2000, Train Loss: 0.2366, Val Loss: 0.2440, Accuracy: 0.0000
# Batch 265/2000, Train Loss: 0.3823, Val Loss: 0.0884, Accuracy: 0.0000
# Batch 270/2000, Train Loss: 0.3560, Val Loss: 0.4105, Accuracy: 0.0000
# Batch 275/2000, Train Loss: 0.1224, Val Loss: 0.2258, Accuracy: 0.0000
# Batch 280/2000, Train Loss: 0.3216, Val Loss: 0.2240, Accuracy: 0.0000
# Batch 285/2000, Train Loss: 0.2096, Val Loss: 0.1471, Accuracy: 0.0000
# Batch 290/2000, Train Loss: 0.1210, Val Loss: 0.2211, Accuracy: 0.0000
# Batch 295/2000, Train Loss: 0.1652, Val Loss: 0.1712, Accuracy: 0.0000
# Batch 300/2000, Train Loss: 0.1595, Val Loss: 0.3358, Accuracy: 0.0000
# Batch 305/2000, Train Loss: 0.1238, Val Loss: 0.1295, Accuracy: 0.0000
# Batch 310/2000, Train Loss: 0.2222, Val Loss: 0.2390, Accuracy: 0.0000
# Batch 315/2000, Train Loss: 0.1352, Val Loss: 0.1508, Accuracy: 0.0000
# Batch 320/2000, Train Loss: 0.1478, Val Loss: 0.4612, Accuracy: 0.0000
# Batch 325/2000, Train Loss: 0.2928, Val Loss: 0.2329, Accuracy: 0.0000
# Batch 330/2000, Train Loss: 0.2728, Val Loss: 0.3308, Accuracy: 0.0000
# Batch 335/2000, Train Loss: 0.1459, Val Loss: 0.2088, Accuracy: 0.0000
# Batch 340/2000, Train Loss: 0.2817, Val Loss: 0.2233, Accuracy: 0.0000
# Batch 345/2000, Train Loss: 0.0939, Val Loss: 0.1476, Accuracy: 0.0000
# Batch 350/2000, Train Loss: 0.2694, Val Loss: 0.1986, Accuracy: 0.0000
# Batch 355/2000, Train Loss: 0.2215, Val Loss: 0.2428, Accuracy: 0.0000
# Batch 360/2000, Train Loss: 0.1932, Val Loss: 0.3000, Accuracy: 0.0000
# Batch 365/2000, Train Loss: 0.2057, Val Loss: 0.3120, Accuracy: 0.0000
# Batch 370/2000, Train Loss: 0.1321, Val Loss: 0.1010, Accuracy: 0.0000
# Batch 375/2000, Train Loss: 0.1680, Val Loss: 0.2140, Accuracy: 0.0000
# Batch 380/2000, Train Loss: 0.1684, Val Loss: 0.1869, Accuracy: 0.0000
# Batch 385/2000, Train Loss: 0.5009, Val Loss: 0.2236, Accuracy: 0.0000
# Batch 390/2000, Train Loss: 0.2005, Val Loss: 0.1365, Accuracy: 0.0000
# Batch 395/2000, Train Loss: 0.2164, Val Loss: 0.0816, Accuracy: 0.0000
# Batch 400/2000, Train Loss: 0.1090, Val Loss: 0.1562, Accuracy: 0.0000
# Batch 405/2000, Train Loss: 0.2355, Val Loss: 0.1164, Accuracy: 0.0000
# Batch 410/2000, Train Loss: 0.1120, Val Loss: 0.0961, Accuracy: 0.0000
# Batch 415/2000, Train Loss: 0.4877, Val Loss: 0.1932, Accuracy: 0.0000
# Batch 420/2000, Train Loss: 0.2094, Val Loss: 0.1189, Accuracy: 0.0000
# Batch 425/2000, Train Loss: 0.1663, Val Loss: 0.0621, Accuracy: 0.0000
# Batch 430/2000, Train Loss: 0.2099, Val Loss: 0.1632, Accuracy: 0.0000
# Batch 435/2000, Train Loss: 0.1638, Val Loss: 0.2128, Accuracy: 0.0000
# Batch 440/2000, Train Loss: 0.2373, Val Loss: 0.0833, Accuracy: 0.0000
# Batch 445/2000, Train Loss: 0.1269, Val Loss: 0.3696, Accuracy: 0.0000
# Batch 450/2000, Train Loss: 0.4986, Val Loss: 0.2792, Accuracy: 0.0000
# Batch 455/2000, Train Loss: 0.2274, Val Loss: 0.3993, Accuracy: 0.0000
# Batch 460/2000, Train Loss: 0.2772, Val Loss: 0.1619, Accuracy: 0.0000
# Batch 465/2000, Train Loss: 0.0885, Val Loss: 0.1321, Accuracy: 0.0000
# Batch 470/2000, Train Loss: 0.1559, Val Loss: 0.1229, Accuracy: 0.0000
# Batch 475/2000, Train Loss: 0.2364, Val Loss: 0.2444, Accuracy: 0.0000
# Batch 480/2000, Train Loss: 0.3282, Val Loss: 0.0663, Accuracy: 0.0000
# Batch 485/2000, Train Loss: 0.2501, Val Loss: 0.0630, Accuracy: 0.0000
# Batch 490/2000, Train Loss: 0.2639, Val Loss: 0.1619, Accuracy: 0.0000
# Batch 495/2000, Train Loss: 0.3162, Val Loss: 0.1953, Accuracy: 0.0000
# Batch 500/2000, Train Loss: 0.1498, Val Loss: 0.1138, Accuracy: 0.0000
# Batch 505/2000, Train Loss: 0.2584, Val Loss: 0.0987, Accuracy: 0.0000
# Batch 510/2000, Train Loss: 0.1997, Val Loss: 0.0787, Accuracy: 0.0000
# Batch 515/2000, Train Loss: 0.1927, Val Loss: 0.3102, Accuracy: 0.0000
# Batch 520/2000, Train Loss: 0.0954, Val Loss: 0.0802, Accuracy: 0.0000
# Batch 525/2000, Train Loss: 0.2265, Val Loss: 0.2832, Accuracy: 0.0000
# Batch 530/2000, Train Loss: 0.1694, Val Loss: 0.0774, Accuracy: 0.0000
# Batch 535/2000, Train Loss: 0.1504, Val Loss: 0.0558, Accuracy: 0.0000
# Batch 540/2000, Train Loss: 0.3510, Val Loss: 0.2371, Accuracy: 0.0000
# Batch 545/2000, Train Loss: 0.2204, Val Loss: 0.1722, Accuracy: 0.0000
# Batch 550/2000, Train Loss: 0.1143, Val Loss: 0.2275, Accuracy: 0.0000
# Batch 555/2000, Train Loss: 0.2848, Val Loss: 0.0687, Accuracy: 0.0000
# Batch 560/2000, Train Loss: 0.2089, Val Loss: 0.1194, Accuracy: 0.0000
# Batch 565/2000, Train Loss: 0.2497, Val Loss: 0.1706, Accuracy: 0.0000
# Batch 570/2000, Train Loss: 0.0571, Val Loss: 0.2986, Accuracy: 0.0000
# Batch 575/2000, Train Loss: 0.1793, Val Loss: 0.0884, Accuracy: 0.0000
# Batch 580/2000, Train Loss: 0.1132, Val Loss: 0.3089, Accuracy: 0.0000
# Batch 585/2000, Train Loss: 0.1502, Val Loss: 0.0820, Accuracy: 0.0000
# Batch 590/2000, Train Loss: 0.0969, Val Loss: 0.1897, Accuracy: 0.0000
# Batch 595/2000, Train Loss: 0.0332, Val Loss: 0.2692, Accuracy: 0.0000
# Batch 600/2000, Train Loss: 0.2096, Val Loss: 0.0799, Accuracy: 0.0000
# Batch 605/2000, Train Loss: 0.1121, Val Loss: 0.2149, Accuracy: 0.0000
# Batch 610/2000, Train Loss: 0.1840, Val Loss: 0.2002, Accuracy: 0.0000
# Batch 615/2000, Train Loss: 0.0946, Val Loss: 0.3243, Accuracy: 0.0000
# Batch 620/2000, Train Loss: 0.1102, Val Loss: 0.0748, Accuracy: 0.0000
# Batch 625/2000, Train Loss: 0.1823, Val Loss: 0.1273, Accuracy: 0.0000
# Batch 630/2000, Train Loss: 0.0545, Val Loss: 0.2882, Accuracy: 0.0000
# Batch 635/2000, Train Loss: 0.0610, Val Loss: 0.2215, Accuracy: 0.0000
# Batch 640/2000, Train Loss: 0.0509, Val Loss: 0.0541, Accuracy: 0.0000
# Batch 645/2000, Train Loss: 0.1562, Val Loss: 0.1320, Accuracy: 0.0000
# Batch 650/2000, Train Loss: 0.1557, Val Loss: 0.1586, Accuracy: 0.0000
# Batch 655/2000, Train Loss: 0.1399, Val Loss: 0.0485, Accuracy: 0.0000
# Batch 660/2000, Train Loss: 0.3016, Val Loss: 0.1613, Accuracy: 0.0000
# Batch 665/2000, Train Loss: 0.1648, Val Loss: 0.3075, Accuracy: 0.0000
# Batch 670/2000, Train Loss: 0.0436, Val Loss: 0.1781, Accuracy: 0.0000
# Batch 675/2000, Train Loss: 0.1852, Val Loss: 0.2420, Accuracy: 0.0000
# Batch 680/2000, Train Loss: 0.0980, Val Loss: 0.2205, Accuracy: 0.0000
# Batch 685/2000, Train Loss: 0.2106, Val Loss: 0.1066, Accuracy: 0.0000
# Batch 690/2000, Train Loss: 0.1713, Val Loss: 0.0200, Accuracy: 0.0000
# Batch 695/2000, Train Loss: 0.0617, Val Loss: 0.1016, Accuracy: 0.0000
# Batch 700/2000, Train Loss: 0.1252, Val Loss: 0.1734, Accuracy: 0.0000
# Batch 705/2000, Train Loss: 0.1741, Val Loss: 0.1209, Accuracy: 0.0000
# Batch 710/2000, Train Loss: 0.1402, Val Loss: 0.1923, Accuracy: 0.0000
# Batch 715/2000, Train Loss: 0.2777, Val Loss: 0.0935, Accuracy: 0.0000
# Batch 720/2000, Train Loss: 0.2070, Val Loss: 0.0536, Accuracy: 0.0000
# Batch 725/2000, Train Loss: 0.1957, Val Loss: 0.1834, Accuracy: 0.0000
# Batch 730/2000, Train Loss: 0.1166, Val Loss: 0.0673, Accuracy: 0.0000
# Batch 735/2000, Train Loss: 0.2018, Val Loss: 0.0698, Accuracy: 0.0000
# Batch 740/2000, Train Loss: 0.1756, Val Loss: 0.1520, Accuracy: 0.0000
# Batch 745/2000, Train Loss: 0.0681, Val Loss: 0.0723, Accuracy: 0.0000
# Batch 750/2000, Train Loss: 0.2008, Val Loss: 0.2058, Accuracy: 0.0000
# Batch 755/2000, Train Loss: 0.0646, Val Loss: 0.1823, Accuracy: 0.0000
# Batch 760/2000, Train Loss: 0.2692, Val Loss: 0.1853, Accuracy: 0.0000
# Batch 765/2000, Train Loss: 0.3351, Val Loss: 0.1887, Accuracy: 0.0000
# Batch 770/2000, Train Loss: 0.2081, Val Loss: 0.1202, Accuracy: 0.0000
# Batch 775/2000, Train Loss: 0.1922, Val Loss: 0.2116, Accuracy: 0.0000
# Batch 780/2000, Train Loss: 0.0634, Val Loss: 0.2311, Accuracy: 0.0000
# Batch 785/2000, Train Loss: 0.1882, Val Loss: 0.1166, Accuracy: 0.0000
# Batch 790/2000, Train Loss: 0.0848, Val Loss: 0.1191, Accuracy: 0.0000
# Batch 795/2000, Train Loss: 0.1289, Val Loss: 0.3866, Accuracy: 0.0000
# Batch 800/2000, Train Loss: 0.2865, Val Loss: 0.0531, Accuracy: 0.0000
# Batch 805/2000, Train Loss: 0.1316, Val Loss: 0.2275, Accuracy: 0.0000
# Batch 810/2000, Train Loss: 0.1368, Val Loss: 0.2476, Accuracy: 0.0000
# Batch 815/2000, Train Loss: 0.2314, Val Loss: 0.2014, Accuracy: 0.0000
# Batch 820/2000, Train Loss: 0.0403, Val Loss: 0.1291, Accuracy: 0.0000
# Batch 825/2000, Train Loss: 0.2793, Val Loss: 0.0553, Accuracy: 0.0000
# Batch 830/2000, Train Loss: 0.0886, Val Loss: 0.1129, Accuracy: 0.0000
# Batch 835/2000, Train Loss: 0.1851, Val Loss: 0.1738, Accuracy: 0.0000
# Batch 840/2000, Train Loss: 0.0968, Val Loss: 0.1879, Accuracy: 0.0000
# Batch 845/2000, Train Loss: 0.1757, Val Loss: 0.0311, Accuracy: 0.0000
# Batch 850/2000, Train Loss: 0.1970, Val Loss: 0.1534, Accuracy: 0.0000
# Batch 855/2000, Train Loss: 0.0679, Val Loss: 0.0377, Accuracy: 0.0000
# Batch 860/2000, Train Loss: 0.2039, Val Loss: 0.3188, Accuracy: 0.0000
# Batch 865/2000, Train Loss: 0.2067, Val Loss: 0.3262, Accuracy: 0.0000
# Batch 870/2000, Train Loss: 0.0405, Val Loss: 0.1563, Accuracy: 0.0000
# Batch 875/2000, Train Loss: 0.0759, Val Loss: 0.0984, Accuracy: 0.0000
# Batch 880/2000, Train Loss: 0.1117, Val Loss: 0.0356, Accuracy: 0.0000
# Batch 885/2000, Train Loss: 0.1493, Val Loss: 0.1559, Accuracy: 0.0000
# Batch 890/2000, Train Loss: 0.0495, Val Loss: 0.1967, Accuracy: 0.0000
# Batch 895/2000, Train Loss: 0.0175, Val Loss: 0.1126, Accuracy: 0.0000
# Batch 900/2000, Train Loss: 0.1252, Val Loss: 0.0756, Accuracy: 0.0000
# Batch 905/2000, Train Loss: 0.2139, Val Loss: 0.0412, Accuracy: 0.0000
# Batch 910/2000, Train Loss: 0.1214, Val Loss: 0.1993, Accuracy: 0.0000
# Batch 915/2000, Train Loss: 0.1112, Val Loss: 0.0143, Accuracy: 0.0000
# Batch 920/2000, Train Loss: 0.0560, Val Loss: 0.2013, Accuracy: 0.0000
# Batch 925/2000, Train Loss: 0.1586, Val Loss: 0.2114, Accuracy: 0.0000
# Batch 930/2000, Train Loss: 0.0867, Val Loss: 0.0469, Accuracy: 0.0000
# Batch 935/2000, Train Loss: 0.0886, Val Loss: 0.1232, Accuracy: 0.0000
# Batch 940/2000, Train Loss: 0.0663, Val Loss: 0.1960, Accuracy: 0.0000
# Batch 945/2000, Train Loss: 0.0837, Val Loss: 0.0490, Accuracy: 0.0000
# Batch 950/2000, Train Loss: 0.1631, Val Loss: 0.0091, Accuracy: 0.0000
# Batch 955/2000, Train Loss: 0.1516, Val Loss: 0.2893, Accuracy: 0.0000
# Batch 960/2000, Train Loss: 0.3089, Val Loss: 0.2691, Accuracy: 0.0000
# Batch 965/2000, Train Loss: 0.3313, Val Loss: 0.5837, Accuracy: 0.0000
# Batch 970/2000, Train Loss: 0.0491, Val Loss: 0.2137, Accuracy: 0.0000
# Batch 975/2000, Train Loss: 0.0666, Val Loss: 0.2070, Accuracy: 0.0000
# Batch 980/2000, Train Loss: 0.0416, Val Loss: 0.1945, Accuracy: 0.0000
# Batch 985/2000, Train Loss: 0.1780, Val Loss: 0.3612, Accuracy: 0.0000
# Batch 990/2000, Train Loss: 0.0358, Val Loss: 0.0974, Accuracy: 0.0000
# Batch 995/2000, Train Loss: 0.1797, Val Loss: 0.2128, Accuracy: 0.0000
# Batch 1000/2000, Train Loss: 0.0733, Val Loss: 0.1908, Accuracy: 0.7422
# Batch 1005/2000, Train Loss: 0.0420, Val Loss: 0.5079, Accuracy: 0.7422
# Batch 1010/2000, Train Loss: 0.2102, Val Loss: 0.1524, Accuracy: 0.7422
# Batch 1015/2000, Train Loss: 0.0512, Val Loss: 0.0167, Accuracy: 0.7422
# Batch 1020/2000, Train Loss: 0.0637, Val Loss: 0.0600, Accuracy: 0.7422
# Batch 1025/2000, Train Loss: 0.1927, Val Loss: 0.1445, Accuracy: 0.7422
# Batch 1030/2000, Train Loss: 0.1966, Val Loss: 0.0940, Accuracy: 0.7422
# Batch 1035/2000, Train Loss: 0.2372, Val Loss: 0.2656, Accuracy: 0.7422
# Batch 1040/2000, Train Loss: 0.1397, Val Loss: 0.2954, Accuracy: 0.7422
# Batch 1045/2000, Train Loss: 0.0825, Val Loss: 0.0367, Accuracy: 0.7422
# Batch 1050/2000, Train Loss: 0.2163, Val Loss: 0.1354, Accuracy: 0.7422
# Batch 1055/2000, Train Loss: 0.1941, Val Loss: 0.0552, Accuracy: 0.7422
# Batch 1060/2000, Train Loss: 0.3073, Val Loss: 0.0527, Accuracy: 0.7422
# Batch 1065/2000, Train Loss: 0.0636, Val Loss: 0.1794, Accuracy: 0.7422
# Batch 1070/2000, Train Loss: 0.1843, Val Loss: 0.1659, Accuracy: 0.7422
# Batch 1075/2000, Train Loss: 0.0220, Val Loss: 0.1605, Accuracy: 0.7422
# Batch 1080/2000, Train Loss: 0.2898, Val Loss: 0.1265, Accuracy: 0.7422
# Batch 1085/2000, Train Loss: 0.0114, Val Loss: 0.1940, Accuracy: 0.7422
# Batch 1090/2000, Train Loss: 0.1139, Val Loss: 0.2080, Accuracy: 0.7422
# Batch 1095/2000, Train Loss: 0.1189, Val Loss: 0.0678, Accuracy: 0.7422
# Batch 1100/2000, Train Loss: 0.1258, Val Loss: 0.0264, Accuracy: 0.7422
# Batch 1105/2000, Train Loss: 0.0347, Val Loss: 0.4141, Accuracy: 0.7422
# Batch 1110/2000, Train Loss: 0.1379, Val Loss: 0.2714, Accuracy: 0.7422
# Batch 1115/2000, Train Loss: 0.1908, Val Loss: 0.0735, Accuracy: 0.7422
# Batch 1120/2000, Train Loss: 0.0707, Val Loss: 0.0173, Accuracy: 0.7422
# Batch 1125/2000, Train Loss: 0.1450, Val Loss: 0.2594, Accuracy: 0.7422
# Batch 1130/2000, Train Loss: 0.1233, Val Loss: 0.1383, Accuracy: 0.7422
# Batch 1135/2000, Train Loss: 0.0904, Val Loss: 0.0851, Accuracy: 0.7422
# Batch 1140/2000, Train Loss: 0.2248, Val Loss: 0.3900, Accuracy: 0.7422
# Batch 1145/2000, Train Loss: 0.0948, Val Loss: 0.0666, Accuracy: 0.7422
# Batch 1150/2000, Train Loss: 0.0666, Val Loss: 0.0446, Accuracy: 0.7422
# Batch 1155/2000, Train Loss: 0.2182, Val Loss: 0.1048, Accuracy: 0.7422
# Batch 1160/2000, Train Loss: 0.2381, Val Loss: 0.1502, Accuracy: 0.7422
# Batch 1165/2000, Train Loss: 0.2517, Val Loss: 0.2691, Accuracy: 0.7422
# Batch 1170/2000, Train Loss: 0.2648, Val Loss: 0.1305, Accuracy: 0.7422
# Batch 1175/2000, Train Loss: 0.2150, Val Loss: 0.1148, Accuracy: 0.7422
# Batch 1180/2000, Train Loss: 0.2065, Val Loss: 0.0359, Accuracy: 0.7422
# Batch 1185/2000, Train Loss: 0.1497, Val Loss: 0.0128, Accuracy: 0.7422
# Batch 1190/2000, Train Loss: 0.2122, Val Loss: 0.1812, Accuracy: 0.7422
# Batch 1195/2000, Train Loss: 0.0922, Val Loss: 0.2003, Accuracy: 0.7422
# Batch 1200/2000, Train Loss: 0.1803, Val Loss: 0.1099, Accuracy: 0.7422
# Batch 1205/2000, Train Loss: 0.1165, Val Loss: 0.3131, Accuracy: 0.7422
# Batch 1210/2000, Train Loss: 0.1757, Val Loss: 0.1780, Accuracy: 0.7422
# Batch 1215/2000, Train Loss: 0.1706, Val Loss: 0.0260, Accuracy: 0.7422
# Batch 1220/2000, Train Loss: 0.0752, Val Loss: 0.1993, Accuracy: 0.7422
# Batch 1225/2000, Train Loss: 0.0621, Val Loss: 0.0493, Accuracy: 0.7422
# Batch 1230/2000, Train Loss: 0.1309, Val Loss: 0.1889, Accuracy: 0.7422
# Batch 1235/2000, Train Loss: 0.2616, Val Loss: 0.2435, Accuracy: 0.7422
# Batch 1240/2000, Train Loss: 0.0742, Val Loss: 0.1420, Accuracy: 0.7422
# Batch 1245/2000, Train Loss: 0.0232, Val Loss: 0.1248, Accuracy: 0.7422
# Batch 1250/2000, Train Loss: 0.1175, Val Loss: 0.2552, Accuracy: 0.7422
# Batch 1255/2000, Train Loss: 0.0182, Val Loss: 0.1131, Accuracy: 0.7422
# Batch 1260/2000, Train Loss: 0.3435, Val Loss: 0.2061, Accuracy: 0.7422
# Batch 1265/2000, Train Loss: 0.1259, Val Loss: 0.2050, Accuracy: 0.7422
# Batch 1270/2000, Train Loss: 0.1962, Val Loss: 0.2545, Accuracy: 0.7422
# Batch 1275/2000, Train Loss: 0.1400, Val Loss: 0.1433, Accuracy: 0.7422
# Batch 1280/2000, Train Loss: 0.2082, Val Loss: 0.0834, Accuracy: 0.7422
# Batch 1285/2000, Train Loss: 0.1564, Val Loss: 0.1499, Accuracy: 0.7422
# Batch 1290/2000, Train Loss: 0.1475, Val Loss: 0.0581, Accuracy: 0.7422
# Batch 1295/2000, Train Loss: 0.2703, Val Loss: 0.0785, Accuracy: 0.7422
# Batch 1300/2000, Train Loss: 0.1526, Val Loss: 0.3971, Accuracy: 0.7422
# Batch 1305/2000, Train Loss: 0.1721, Val Loss: 0.0639, Accuracy: 0.7422
# Batch 1310/2000, Train Loss: 0.1400, Val Loss: 0.2013, Accuracy: 0.7422
# Batch 1315/2000, Train Loss: 0.1905, Val Loss: 0.1370, Accuracy: 0.7422
# Batch 1320/2000, Train Loss: 0.1566, Val Loss: 0.1782, Accuracy: 0.7422
# Batch 1325/2000, Train Loss: 0.0782, Val Loss: 0.2119, Accuracy: 0.7422
# Batch 1330/2000, Train Loss: 0.2049, Val Loss: 0.1396, Accuracy: 0.7422
# Batch 1335/2000, Train Loss: 0.0771, Val Loss: 0.0345, Accuracy: 0.7422
# Batch 1340/2000, Train Loss: 0.1179, Val Loss: 0.0266, Accuracy: 0.7422
# Batch 1345/2000, Train Loss: 0.4208, Val Loss: 0.0734, Accuracy: 0.7422
# Batch 1350/2000, Train Loss: 0.1214, Val Loss: 0.3022, Accuracy: 0.7422
# Batch 1355/2000, Train Loss: 0.1780, Val Loss: 0.2725, Accuracy: 0.7422
# Batch 1360/2000, Train Loss: 0.1991, Val Loss: 0.2159, Accuracy: 0.7422
# Batch 1365/2000, Train Loss: 0.0936, Val Loss: 0.2830, Accuracy: 0.7422
# Batch 1370/2000, Train Loss: 0.1586, Val Loss: 0.2820, Accuracy: 0.7422
# Batch 1375/2000, Train Loss: 0.0233, Val Loss: 0.1260, Accuracy: 0.7422
# Batch 1380/2000, Train Loss: 0.2438, Val Loss: 0.0373, Accuracy: 0.7422
# Batch 1385/2000, Train Loss: 0.2517, Val Loss: 0.0816, Accuracy: 0.7422
# Batch 1390/2000, Train Loss: 0.0391, Val Loss: 0.2983, Accuracy: 0.7422
# Batch 1395/2000, Train Loss: 0.1470, Val Loss: 0.3072, Accuracy: 0.7422
# Batch 1400/2000, Train Loss: 0.0131, Val Loss: 0.0545, Accuracy: 0.7422
# Batch 1405/2000, Train Loss: 0.1552, Val Loss: 0.1432, Accuracy: 0.7422
# Batch 1410/2000, Train Loss: 0.0488, Val Loss: 0.1578, Accuracy: 0.7422
# Batch 1415/2000, Train Loss: 0.0605, Val Loss: 0.2544, Accuracy: 0.7422
# Batch 1420/2000, Train Loss: 0.4307, Val Loss: 0.0948, Accuracy: 0.7422
# Batch 1425/2000, Train Loss: 0.0253, Val Loss: 0.1294, Accuracy: 0.7422
# Batch 1430/2000, Train Loss: 0.1123, Val Loss: 0.1528, Accuracy: 0.7422
# Batch 1435/2000, Train Loss: 0.0565, Val Loss: 0.2117, Accuracy: 0.7422
# Batch 1440/2000, Train Loss: 0.1870, Val Loss: 0.2129, Accuracy: 0.7422
# Batch 1445/2000, Train Loss: 0.2090, Val Loss: 0.2042, Accuracy: 0.7422
# Batch 1450/2000, Train Loss: 0.0887, Val Loss: 0.0388, Accuracy: 0.7422
# Batch 1455/2000, Train Loss: 0.0842, Val Loss: 0.0832, Accuracy: 0.7422
# Batch 1460/2000, Train Loss: 0.2001, Val Loss: 0.1322, Accuracy: 0.7422
# Batch 1465/2000, Train Loss: 0.1636, Val Loss: 0.2633, Accuracy: 0.7422
# Batch 1470/2000, Train Loss: 0.2502, Val Loss: 0.1457, Accuracy: 0.7422
# Batch 1475/2000, Train Loss: 0.0836, Val Loss: 0.1557, Accuracy: 0.7422
# Batch 1480/2000, Train Loss: 0.0340, Val Loss: 0.2340, Accuracy: 0.7422
# Batch 1485/2000, Train Loss: 0.0751, Val Loss: 0.1461, Accuracy: 0.7422
# Batch 1490/2000, Train Loss: 0.0611, Val Loss: 0.0414, Accuracy: 0.7422
# Batch 1495/2000, Train Loss: 0.0914, Val Loss: 0.1613, Accuracy: 0.7422
# Batch 1500/2000, Train Loss: 0.1398, Val Loss: 0.1728, Accuracy: 0.7422
# Batch 1505/2000, Train Loss: 0.2868, Val Loss: 0.1543, Accuracy: 0.7422
# Batch 1510/2000, Train Loss: 0.0701, Val Loss: 0.0581, Accuracy: 0.7422
# Batch 1515/2000, Train Loss: 0.0760, Val Loss: 0.2957, Accuracy: 0.7422
# Batch 1520/2000, Train Loss: 0.0697, Val Loss: 0.0783, Accuracy: 0.7422
# Batch 1525/2000, Train Loss: 0.1457, Val Loss: 0.0922, Accuracy: 0.7422
# Batch 1530/2000, Train Loss: 0.1110, Val Loss: 0.1177, Accuracy: 0.7422
# Batch 1535/2000, Train Loss: 0.1620, Val Loss: 0.0580, Accuracy: 0.7422
# Batch 1540/2000, Train Loss: 0.2091, Val Loss: 0.1564, Accuracy: 0.7422
# Batch 1545/2000, Train Loss: 0.2743, Val Loss: 0.0601, Accuracy: 0.7422
# Batch 1550/2000, Train Loss: 0.2164, Val Loss: 0.1788, Accuracy: 0.7422
# Batch 1555/2000, Train Loss: 0.0189, Val Loss: 0.2150, Accuracy: 0.7422
# Batch 1560/2000, Train Loss: 0.1808, Val Loss: 0.0751, Accuracy: 0.7422
# Batch 1565/2000, Train Loss: 0.0908, Val Loss: 0.0746, Accuracy: 0.7422
# Batch 1570/2000, Train Loss: 0.0198, Val Loss: 0.0591, Accuracy: 0.7422
# Batch 1575/2000, Train Loss: 0.1686, Val Loss: 0.0653, Accuracy: 0.7422
# Batch 1580/2000, Train Loss: 0.3229, Val Loss: 0.2730, Accuracy: 0.7422
# Batch 1585/2000, Train Loss: 0.0403, Val Loss: 0.1593, Accuracy: 0.7422
# Batch 1590/2000, Train Loss: 0.0612, Val Loss: 0.4148, Accuracy: 0.7422
# Batch 1595/2000, Train Loss: 0.0245, Val Loss: 0.1086, Accuracy: 0.7422
# Batch 1600/2000, Train Loss: 0.2641, Val Loss: 0.2002, Accuracy: 0.7422
# Batch 1605/2000, Train Loss: 0.0203, Val Loss: 0.0455, Accuracy: 0.7422
# Batch 1610/2000, Train Loss: 0.1471, Val Loss: 0.3089, Accuracy: 0.7422
# Batch 1615/2000, Train Loss: 0.1740, Val Loss: 0.2525, Accuracy: 0.7422
# Batch 1620/2000, Train Loss: 0.0434, Val Loss: 0.1736, Accuracy: 0.7422
# Batch 1625/2000, Train Loss: 0.2457, Val Loss: 0.1523, Accuracy: 0.7422
# Batch 1630/2000, Train Loss: 0.1065, Val Loss: 0.0631, Accuracy: 0.7422
# Batch 1635/2000, Train Loss: 0.1387, Val Loss: 0.1362, Accuracy: 0.7422
# Batch 1640/2000, Train Loss: 0.1473, Val Loss: 0.1991, Accuracy: 0.7422
# Batch 1645/2000, Train Loss: 0.0162, Val Loss: 0.0417, Accuracy: 0.7422
# Batch 1650/2000, Train Loss: 0.1484, Val Loss: 0.0689, Accuracy: 0.7422
# Batch 1655/2000, Train Loss: 0.2064, Val Loss: 0.0446, Accuracy: 0.7422
# Batch 1660/2000, Train Loss: 0.1028, Val Loss: 0.0361, Accuracy: 0.7422
# Batch 1665/2000, Train Loss: 0.0844, Val Loss: 0.2694, Accuracy: 0.7422
# Batch 1670/2000, Train Loss: 0.1565, Val Loss: 0.0608, Accuracy: 0.7422
# Batch 1675/2000, Train Loss: 0.2261, Val Loss: 0.1294, Accuracy: 0.7422
# Batch 1680/2000, Train Loss: 0.0195, Val Loss: 0.3440, Accuracy: 0.7422
# Batch 1685/2000, Train Loss: 0.0272, Val Loss: 0.1222, Accuracy: 0.7422
# Batch 1690/2000, Train Loss: 0.0487, Val Loss: 0.1789, Accuracy: 0.7422
# Batch 1695/2000, Train Loss: 0.3362, Val Loss: 0.0302, Accuracy: 0.7422
# Batch 1700/2000, Train Loss: 0.1699, Val Loss: 0.1562, Accuracy: 0.7422
# Batch 1705/2000, Train Loss: 0.1838, Val Loss: 0.0846, Accuracy: 0.7422
# Batch 1710/2000, Train Loss: 0.1659, Val Loss: 0.2882, Accuracy: 0.7422
# Batch 1715/2000, Train Loss: 0.0495, Val Loss: 0.0825, Accuracy: 0.7422
# Batch 1720/2000, Train Loss: 0.0488, Val Loss: 0.0501, Accuracy: 0.7422
# Batch 1725/2000, Train Loss: 0.0667, Val Loss: 0.1075, Accuracy: 0.7422
# Batch 1730/2000, Train Loss: 0.2598, Val Loss: 0.1402, Accuracy: 0.7422
# Batch 1735/2000, Train Loss: 0.1763, Val Loss: 0.2049, Accuracy: 0.7422
# Batch 1740/2000, Train Loss: 0.1613, Val Loss: 0.0801, Accuracy: 0.7422
# Batch 1745/2000, Train Loss: 0.1353, Val Loss: 0.0466, Accuracy: 0.7422
# Batch 1750/2000, Train Loss: 0.1341, Val Loss: 0.1157, Accuracy: 0.7422
# Batch 1755/2000, Train Loss: 0.0630, Val Loss: 0.2348, Accuracy: 0.7422
# Batch 1760/2000, Train Loss: 0.2298, Val Loss: 0.2415, Accuracy: 0.7422
# Batch 1765/2000, Train Loss: 0.0968, Val Loss: 0.3873, Accuracy: 0.7422
# Batch 1770/2000, Train Loss: 0.1807, Val Loss: 0.0665, Accuracy: 0.7422
# Batch 1775/2000, Train Loss: 0.1706, Val Loss: 0.1815, Accuracy: 0.7422
# Batch 1780/2000, Train Loss: 0.2450, Val Loss: 0.1430, Accuracy: 0.7422
# Batch 1785/2000, Train Loss: 0.1677, Val Loss: 0.0848, Accuracy: 0.7422
# Batch 1790/2000, Train Loss: 0.1555, Val Loss: 0.0220, Accuracy: 0.7422
# Batch 1795/2000, Train Loss: 0.0521, Val Loss: 0.0713, Accuracy: 0.7422
# Batch 1800/2000, Train Loss: 0.0908, Val Loss: 0.0357, Accuracy: 0.7422
# Batch 1805/2000, Train Loss: 0.2576, Val Loss: 0.0331, Accuracy: 0.7422
# Batch 1810/2000, Train Loss: 0.0609, Val Loss: 0.1340, Accuracy: 0.7422
# Batch 1815/2000, Train Loss: 0.0383, Val Loss: 0.1477, Accuracy: 0.7422
# Batch 1820/2000, Train Loss: 0.2202, Val Loss: 0.0526, Accuracy: 0.7422
# Batch 1825/2000, Train Loss: 0.1385, Val Loss: 0.0825, Accuracy: 0.7422
# Batch 1830/2000, Train Loss: 0.1697, Val Loss: 0.1127, Accuracy: 0.7422
# Batch 1835/2000, Train Loss: 0.1452, Val Loss: 0.0583, Accuracy: 0.7422
# Batch 1840/2000, Train Loss: 0.1430, Val Loss: 0.2738, Accuracy: 0.7422
# Batch 1845/2000, Train Loss: 0.1549, Val Loss: 0.0663, Accuracy: 0.7422
# Batch 1850/2000, Train Loss: 0.2181, Val Loss: 0.2357, Accuracy: 0.7422
# Batch 1855/2000, Train Loss: 0.1375, Val Loss: 0.1800, Accuracy: 0.7422
# Batch 1860/2000, Train Loss: 0.2333, Val Loss: 0.0976, Accuracy: 0.7422
# Batch 1865/2000, Train Loss: 0.1911, Val Loss: 0.1914, Accuracy: 0.7422
# Batch 1870/2000, Train Loss: 0.0303, Val Loss: 0.1136, Accuracy: 0.7422
# Batch 1875/2000, Train Loss: 0.1457, Val Loss: 0.1160, Accuracy: 0.7422
# Batch 1880/2000, Train Loss: 0.1588, Val Loss: 0.1781, Accuracy: 0.7422
# Batch 1885/2000, Train Loss: 0.0885, Val Loss: 0.0674, Accuracy: 0.7422
# Batch 1890/2000, Train Loss: 0.0608, Val Loss: 0.0299, Accuracy: 0.7422
# Batch 1895/2000, Train Loss: 0.3089, Val Loss: 0.0490, Accuracy: 0.7422
# Batch 1900/2000, Train Loss: 0.1602, Val Loss: 0.0372, Accuracy: 0.7422
# Batch 1905/2000, Train Loss: 0.0681, Val Loss: 0.2635, Accuracy: 0.7422
# Batch 1910/2000, Train Loss: 0.0410, Val Loss: 0.0382, Accuracy: 0.7422
# Batch 1915/2000, Train Loss: 0.1674, Val Loss: 0.2158, Accuracy: 0.7422
# Batch 1920/2000, Train Loss: 0.0225, Val Loss: 0.1664, Accuracy: 0.7422
# Batch 1925/2000, Train Loss: 0.1151, Val Loss: 0.0258, Accuracy: 0.7422
# Batch 1930/2000, Train Loss: 0.1709, Val Loss: 0.2023, Accuracy: 0.7422
# Batch 1935/2000, Train Loss: 0.1707, Val Loss: 0.0310, Accuracy: 0.7422
# Batch 1940/2000, Train Loss: 0.1569, Val Loss: 0.1600, Accuracy: 0.7422
# Batch 1945/2000, Train Loss: 0.2768, Val Loss: 0.1996, Accuracy: 0.7422
# Batch 1950/2000, Train Loss: 0.2330, Val Loss: 0.0227, Accuracy: 0.7422
# Batch 1955/2000, Train Loss: 0.2284, Val Loss: 0.1338, Accuracy: 0.7422
# Batch 1960/2000, Train Loss: 0.0624, Val Loss: 0.2045, Accuracy: 0.7422
# Batch 1965/2000, Train Loss: 0.0333, Val Loss: 0.0889, Accuracy: 0.7422
# Batch 1970/2000, Train Loss: 0.0426, Val Loss: 0.0570, Accuracy: 0.7422
# Batch 1975/2000, Train Loss: 0.1410, Val Loss: 0.0437, Accuracy: 0.7422
# Batch 1980/2000, Train Loss: 0.1348, Val Loss: 0.2225, Accuracy: 0.7422
# Batch 1985/2000, Train Loss: 0.0504, Val Loss: 0.2713, Accuracy: 0.7422
# Batch 1990/2000, Train Loss: 0.3582, Val Loss: 0.0535, Accuracy: 0.7422
# Batch 1995/2000, Train Loss: 0.2583, Val Loss: 0.1298, Accuracy: 0.7422
# Error decoding output: list index out of range
# Batch 2000/2000, Train Loss: 0.0409, Val Loss: 0.0250, Accuracy: 0.9014
# Epoch 1 time: 403.58 seconds
# Epoch 2/50
# Batch 5/2000, Train Loss: 0.0188, Val Loss: 0.0526, Accuracy: 0.9014
# Batch 10/2000, Train Loss: 0.1542, Val Loss: 0.0691, Accuracy: 0.9014
# Batch 15/2000, Train Loss: 0.0541, Val Loss: 0.0472, Accuracy: 0.9014
# Batch 20/2000, Train Loss: 0.2031, Val Loss: 0.0583, Accuracy: 0.9014
# Batch 25/2000, Train Loss: 0.1680, Val Loss: 0.1706, Accuracy: 0.9014
# Batch 30/2000, Train Loss: 0.0428, Val Loss: 0.0217, Accuracy: 0.9014
# Batch 35/2000, Train Loss: 0.0620, Val Loss: 0.2273, Accuracy: 0.9014
# Batch 40/2000, Train Loss: 0.0410, Val Loss: 0.1223, Accuracy: 0.9014
# Batch 45/2000, Train Loss: 0.1384, Val Loss: 0.1985, Accuracy: 0.9014
# Batch 50/2000, Train Loss: 0.3196, Val Loss: 0.0458, Accuracy: 0.9014
# Batch 55/2000, Train Loss: 0.1329, Val Loss: 0.0407, Accuracy: 0.9014
# Batch 60/2000, Train Loss: 0.0238, Val Loss: 0.1265, Accuracy: 0.9014
# Batch 65/2000, Train Loss: 0.0831, Val Loss: 0.0442, Accuracy: 0.9014
# Batch 70/2000, Train Loss: 0.0475, Val Loss: 0.1988, Accuracy: 0.9014
# Batch 75/2000, Train Loss: 0.1593, Val Loss: 0.0477, Accuracy: 0.9014
# Batch 80/2000, Train Loss: 0.1276, Val Loss: 0.0142, Accuracy: 0.9014
# Batch 85/2000, Train Loss: 0.1190, Val Loss: 0.0401, Accuracy: 0.9014
# Batch 90/2000, Train Loss: 0.2176, Val Loss: 0.0680, Accuracy: 0.9014
# Batch 95/2000, Train Loss: 0.1120, Val Loss: 0.0346, Accuracy: 0.9014
# Batch 100/2000, Train Loss: 0.1648, Val Loss: 0.2157, Accuracy: 0.9014
# Batch 105/2000, Train Loss: 0.1686, Val Loss: 0.1376, Accuracy: 0.9014
# Batch 110/2000, Train Loss: 0.0718, Val Loss: 0.1231, Accuracy: 0.9014
# Batch 115/2000, Train Loss: 0.1361, Val Loss: 0.1628, Accuracy: 0.9014
# Batch 120/2000, Train Loss: 0.1563, Val Loss: 0.0768, Accuracy: 0.9014
# Batch 125/2000, Train Loss: 0.1012, Val Loss: 0.1724, Accuracy: 0.9014
# Batch 130/2000, Train Loss: 0.1653, Val Loss: 0.1053, Accuracy: 0.9014
# Batch 135/2000, Train Loss: 0.2087, Val Loss: 0.1932, Accuracy: 0.9014
# Batch 140/2000, Train Loss: 0.0481, Val Loss: 0.1823, Accuracy: 0.9014
# Batch 145/2000, Train Loss: 0.0761, Val Loss: 0.1303, Accuracy: 0.9014
# Batch 150/2000, Train Loss: 0.1713, Val Loss: 0.1178, Accuracy: 0.9014
# Batch 155/2000, Train Loss: 0.0811, Val Loss: 0.2517, Accuracy: 0.9014
# Batch 160/2000, Train Loss: 0.2401, Val Loss: 0.1291, Accuracy: 0.9014
# Batch 165/2000, Train Loss: 0.0158, Val Loss: 0.1518, Accuracy: 0.9014
# Batch 170/2000, Train Loss: 0.0566, Val Loss: 0.2114, Accuracy: 0.9014
# Batch 175/2000, Train Loss: 0.0198, Val Loss: 0.1066, Accuracy: 0.9014
# Batch 180/2000, Train Loss: 0.0371, Val Loss: 0.1625, Accuracy: 0.9014
# Batch 185/2000, Train Loss: 0.2572, Val Loss: 0.0904, Accuracy: 0.9014
# Batch 190/2000, Train Loss: 0.1660, Val Loss: 0.0376, Accuracy: 0.9014
# Batch 195/2000, Train Loss: 0.1603, Val Loss: 0.3383, Accuracy: 0.9014
# Batch 200/2000, Train Loss: 0.0954, Val Loss: 0.0410, Accuracy: 0.9014
# Batch 205/2000, Train Loss: 0.1518, Val Loss: 0.2830, Accuracy: 0.9014
# Batch 210/2000, Train Loss: 0.1132, Val Loss: 0.1760, Accuracy: 0.9014
# Batch 215/2000, Train Loss: 0.0466, Val Loss: 0.2926, Accuracy: 0.9014
# Batch 220/2000, Train Loss: 0.2092, Val Loss: 0.2887, Accuracy: 0.9014
# Batch 225/2000, Train Loss: 0.0225, Val Loss: 0.0459, Accuracy: 0.9014
# Batch 230/2000, Train Loss: 0.1514, Val Loss: 0.0323, Accuracy: 0.9014
# Batch 235/2000, Train Loss: 0.3517, Val Loss: 0.0769, Accuracy: 0.9014
# Batch 240/2000, Train Loss: 0.0565, Val Loss: 0.0454, Accuracy: 0.9014
# Batch 245/2000, Train Loss: 0.0833, Val Loss: 0.0400, Accuracy: 0.9014
# Batch 250/2000, Train Loss: 0.0571, Val Loss: 0.0667, Accuracy: 0.9014
# Batch 255/2000, Train Loss: 0.0414, Val Loss: 0.2157, Accuracy: 0.9014
# Batch 260/2000, Train Loss: 0.1916, Val Loss: 0.0470, Accuracy: 0.9014
# Batch 265/2000, Train Loss: 0.0899, Val Loss: 0.3237, Accuracy: 0.9014
# Batch 270/2000, Train Loss: 0.2743, Val Loss: 0.2719, Accuracy: 0.9014
# Batch 275/2000, Train Loss: 0.0113, Val Loss: 0.1705, Accuracy: 0.9014
# Batch 280/2000, Train Loss: 0.1057, Val Loss: 0.1475, Accuracy: 0.9014
# Batch 285/2000, Train Loss: 0.2000, Val Loss: 0.1504, Accuracy: 0.9014
# Batch 290/2000, Train Loss: 0.1121, Val Loss: 0.1322, Accuracy: 0.9014
# Batch 295/2000, Train Loss: 0.1242, Val Loss: 0.1412, Accuracy: 0.9014
# Batch 300/2000, Train Loss: 0.0846, Val Loss: 0.0337, Accuracy: 0.9014
# Batch 305/2000, Train Loss: 0.1974, Val Loss: 0.2352, Accuracy: 0.9014
# Batch 310/2000, Train Loss: 0.1691, Val Loss: 0.1607, Accuracy: 0.9014
# Batch 315/2000, Train Loss: 0.1808, Val Loss: 0.0448, Accuracy: 0.9014
# Batch 320/2000, Train Loss: 0.0495, Val Loss: 0.1596, Accuracy: 0.9014
# Batch 325/2000, Train Loss: 0.2124, Val Loss: 0.2938, Accuracy: 0.9014
# Batch 330/2000, Train Loss: 0.0087, Val Loss: 0.0710, Accuracy: 0.9014
# Batch 335/2000, Train Loss: 0.0478, Val Loss: 0.2010, Accuracy: 0.9014
# Batch 340/2000, Train Loss: 0.1134, Val Loss: 0.1368, Accuracy: 0.9014
# Batch 345/2000, Train Loss: 0.1424, Val Loss: 0.0827, Accuracy: 0.9014
# Batch 350/2000, Train Loss: 0.1307, Val Loss: 0.0278, Accuracy: 0.9014
# Batch 355/2000, Train Loss: 0.1586, Val Loss: 0.0541, Accuracy: 0.9014
# Batch 360/2000, Train Loss: 0.0595, Val Loss: 0.1692, Accuracy: 0.9014
# Batch 365/2000, Train Loss: 0.0476, Val Loss: 0.1710, Accuracy: 0.9014
# Batch 370/2000, Train Loss: 0.0606, Val Loss: 0.2170, Accuracy: 0.9014
# Batch 375/2000, Train Loss: 0.2870, Val Loss: 0.2525, Accuracy: 0.9014
# Batch 380/2000, Train Loss: 0.0270, Val Loss: 0.0339, Accuracy: 0.9014
# Batch 385/2000, Train Loss: 0.3197, Val Loss: 0.3019, Accuracy: 0.9014
# Batch 390/2000, Train Loss: 0.1355, Val Loss: 0.0520, Accuracy: 0.9014
# Batch 395/2000, Train Loss: 0.2789, Val Loss: 0.1572, Accuracy: 0.9014
# Batch 400/2000, Train Loss: 0.2377, Val Loss: 0.2943, Accuracy: 0.9014
# Batch 405/2000, Train Loss: 0.0999, Val Loss: 0.2114, Accuracy: 0.9014
# Batch 410/2000, Train Loss: 0.1609, Val Loss: 0.1132, Accuracy: 0.9014
# Batch 415/2000, Train Loss: 0.1900, Val Loss: 0.1178, Accuracy: 0.9014
# Batch 420/2000, Train Loss: 0.1113, Val Loss: 0.0419, Accuracy: 0.9014
# Batch 425/2000, Train Loss: 0.0582, Val Loss: 0.3767, Accuracy: 0.9014
# Batch 430/2000, Train Loss: 0.0599, Val Loss: 0.0553, Accuracy: 0.9014
# Batch 435/2000, Train Loss: 0.0488, Val Loss: 0.1480, Accuracy: 0.9014
# Batch 440/2000, Train Loss: 0.1335, Val Loss: 0.0267, Accuracy: 0.9014
# Batch 445/2000, Train Loss: 0.1098, Val Loss: 0.0439, Accuracy: 0.9014
# Batch 450/2000, Train Loss: 0.1388, Val Loss: 0.0359, Accuracy: 0.9014
# Batch 455/2000, Train Loss: 0.2577, Val Loss: 0.2139, Accuracy: 0.9014
# Batch 460/2000, Train Loss: 0.1943, Val Loss: 0.0227, Accuracy: 0.9014
# Batch 465/2000, Train Loss: 0.0417, Val Loss: 0.1448, Accuracy: 0.9014
# Batch 470/2000, Train Loss: 0.1525, Val Loss: 0.0564, Accuracy: 0.9014
# Batch 475/2000, Train Loss: 0.0553, Val Loss: 0.2606, Accuracy: 0.9014
# Batch 480/2000, Train Loss: 0.2465, Val Loss: 0.0773, Accuracy: 0.9014
# Batch 485/2000, Train Loss: 0.0523, Val Loss: 0.1269, Accuracy: 0.9014
# Batch 490/2000, Train Loss: 0.0414, Val Loss: 0.2120, Accuracy: 0.9014
# Batch 495/2000, Train Loss: 0.0294, Val Loss: 0.0408, Accuracy: 0.9014
# Batch 500/2000, Train Loss: 0.1092, Val Loss: 0.0497, Accuracy: 0.9014
# Batch 505/2000, Train Loss: 0.0337, Val Loss: 0.0159, Accuracy: 0.9014
# Batch 510/2000, Train Loss: 0.0713, Val Loss: 0.1967, Accuracy: 0.9014
# Batch 515/2000, Train Loss: 0.0171, Val Loss: 0.0627, Accuracy: 0.9014
# Batch 520/2000, Train Loss: 0.1420, Val Loss: 0.1558, Accuracy: 0.9014
# Batch 525/2000, Train Loss: 0.1690, Val Loss: 0.2023, Accuracy: 0.9014
# Batch 530/2000, Train Loss: 0.1773, Val Loss: 0.1933, Accuracy: 0.9014
# Batch 535/2000, Train Loss: 0.0210, Val Loss: 0.1389, Accuracy: 0.9014
# Batch 540/2000, Train Loss: 0.0485, Val Loss: 0.0285, Accuracy: 0.9014
# Batch 545/2000, Train Loss: 0.0688, Val Loss: 0.0772, Accuracy: 0.9014
# Batch 550/2000, Train Loss: 0.1699, Val Loss: 0.0852, Accuracy: 0.9014
# Batch 555/2000, Train Loss: 0.2744, Val Loss: 0.1789, Accuracy: 0.9014
# Batch 560/2000, Train Loss: 0.2111, Val Loss: 0.1989, Accuracy: 0.9014
# Batch 565/2000, Train Loss: 0.1181, Val Loss: 0.2793, Accuracy: 0.9014
# Batch 570/2000, Train Loss: 0.1378, Val Loss: 0.1724, Accuracy: 0.9014
# Batch 575/2000, Train Loss: 0.1601, Val Loss: 0.1506, Accuracy: 0.9014
# Batch 580/2000, Train Loss: 0.1435, Val Loss: 0.0291, Accuracy: 0.9014
# Batch 585/2000, Train Loss: 0.1342, Val Loss: 0.1726, Accuracy: 0.9014
# Batch 590/2000, Train Loss: 0.0268, Val Loss: 0.1081, Accuracy: 0.9014
# Batch 595/2000, Train Loss: 0.2343, Val Loss: 0.1417, Accuracy: 0.9014
# Batch 600/2000, Train Loss: 0.1207, Val Loss: 0.4237, Accuracy: 0.9014
# Batch 605/2000, Train Loss: 0.0701, Val Loss: 0.1453, Accuracy: 0.9014
# Batch 610/2000, Train Loss: 0.2699, Val Loss: 0.1616, Accuracy: 0.9014
# Batch 615/2000, Train Loss: 0.0497, Val Loss: 0.1461, Accuracy: 0.9014
# Batch 620/2000, Train Loss: 0.0584, Val Loss: 0.1438, Accuracy: 0.9014
# Batch 625/2000, Train Loss: 0.1338, Val Loss: 0.1924, Accuracy: 0.9014
# ...
# Batch 910/2000, Train Loss: 0.0178, Val Loss: 0.0324, Accuracy: 0.9988
# Batch 915/2000, Train Loss: 0.0603, Val Loss: 0.0360, Accuracy: 0.9988
# Batch 920/2000, Train Loss: 0.1091, Val Loss: 0.0606, Accuracy: 0.9988
# Batch 925/2000, Train Loss: 0.0966, Val Loss: 0.0380, Accuracy: 0.9988
# Batch 930/2000, Train Loss: 0.0297, Val Loss: 0.1026, Accuracy: 0.9988
# Batch 935/2000, Train Loss: 0.1892, Val Loss: 0.1833, Accuracy: 0.9988
# Batch 940/2000, Train Loss: 0.0880, Val Loss: 0.0986, Accuracy: 0.9988
# Batch 945/2000, Train Loss: 0.0813, Val Loss: 0.1275, Accuracy: 0.9988
# Batch 950/2000, Train Loss: 0.1073, Val Loss: 0.0449, Accuracy: 0.9988
# Batch 955/2000, Train Loss: 0.0970, Val Loss: 0.1219, Accuracy: 0.9988
# Batch 960/2000, Train Loss: 0.0444, Val Loss: 0.0570, Accuracy: 0.9988
# Batch 965/2000, Train Loss: 0.2113, Val Loss: 0.0517, Accuracy: 0.9988
# Batch 970/2000, Train Loss: 0.0430, Val Loss: 0.1047, Accuracy: 0.9988
# Batch 975/2000, Train Loss: 0.1665, Val Loss: 0.0720, Accuracy: 0.9988
# Batch 980/2000, Train Loss: 0.1071, Val Loss: 0.1950, Accuracy: 0.9988
# Batch 985/2000, Train Loss: 0.1345, Val Loss: 0.1201, Accuracy: 0.9988
# Batch 990/2000, Train Loss: 0.1624, Val Loss: 0.0419, Accuracy: 0.9988
# Batch 995/2000, Train Loss: 0.1776, Val Loss: 0.0485, Accuracy: 0.9988
# Batch 1000/2000, Train Loss: 0.0345, Val Loss: 0.0310, Accuracy: 0.9992
# Batch 1005/2000, Train Loss: 0.1439, Val Loss: 0.0697, Accuracy: 0.9992
# Batch 1010/2000, Train Loss: 0.0570, Val Loss: 0.0316, Accuracy: 0.9992
# Batch 1015/2000, Train Loss: 0.1178, Val Loss: 0.1310, Accuracy: 0.9992
# Batch 1020/2000, Train Loss: 0.1537, Val Loss: 0.0873, Accuracy: 0.9992
# Batch 1025/2000, Train Loss: 0.0677, Val Loss: 0.0495, Accuracy: 0.9992
# Batch 1030/2000, Train Loss: 0.0389, Val Loss: 0.2404, Accuracy: 0.9992
# Batch 1035/2000, Train Loss: 0.0437, Val Loss: 0.0633, Accuracy: 0.9992
# Batch 1040/2000, Train Loss: 0.0769, Val Loss: 0.0946, Accuracy: 0.9992
# Batch 1045/2000, Train Loss: 0.0789, Val Loss: 0.0214, Accuracy: 0.9992
# Batch 1050/2000, Train Loss: 0.2170, Val Loss: 0.0927, Accuracy: 0.9992
# Batch 1055/2000, Train Loss: 0.1307, Val Loss: 0.1663, Accuracy: 0.9992
# Batch 1060/2000, Train Loss: 0.1150, Val Loss: 0.0870, Accuracy: 0.9992
# Batch 1065/2000, Train Loss: 0.0408, Val Loss: 0.1135, Accuracy: 0.9992
# Batch 1070/2000, Train Loss: 0.1829, Val Loss: 0.0293, Accuracy: 0.9992
# Batch 1075/2000, Train Loss: 0.0677, Val Loss: 0.0935, Accuracy: 0.9992
# Batch 1080/2000, Train Loss: 0.1126, Val Loss: 0.1507, Accuracy: 0.9992
# Batch 1085/2000, Train Loss: 0.1087, Val Loss: 0.1072, Accuracy: 0.9992
# Batch 1090/2000, Train Loss: 0.1237, Val Loss: 0.0905, Accuracy: 0.9992
# Batch 1095/2000, Train Loss: 0.0983, Val Loss: 0.1538, Accuracy: 0.9992
# Batch 1100/2000, Train Loss: 0.0744, Val Loss: 0.0575, Accuracy: 0.9992
# Batch 1105/2000, Train Loss: 0.0239, Val Loss: 0.1704, Accuracy: 0.9992
# Batch 1110/2000, Train Loss: 0.1071, Val Loss: 0.1006, Accuracy: 0.9992
# Batch 1115/2000, Train Loss: 0.1239, Val Loss: 0.1472, Accuracy: 0.9992
# Batch 1120/2000, Train Loss: 0.1688, Val Loss: 0.0376, Accuracy: 0.9992
# Batch 1125/2000, Train Loss: 0.1601, Val Loss: 0.1750, Accuracy: 0.9992
# Batch 1130/2000, Train Loss: 0.0655, Val Loss: 0.1413, Accuracy: 0.9992
# Batch 1135/2000, Train Loss: 0.0197, Val Loss: 0.0103, Accuracy: 0.9992
# Batch 1140/2000, Train Loss: 0.0787, Val Loss: 0.0665, Accuracy: 0.9992
# Batch 1145/2000, Train Loss: 0.0208, Val Loss: 0.1164, Accuracy: 0.9992
# Batch 1150/2000, Train Loss: 0.0115, Val Loss: 0.1640, Accuracy: 0.9992
# Batch 1155/2000, Train Loss: 0.0174, Val Loss: 0.0247, Accuracy: 0.9992
# Batch 1160/2000, Train Loss: 0.1231, Val Loss: 0.0946, Accuracy: 0.9992
# Batch 1165/2000, Train Loss: 0.0489, Val Loss: 0.1537, Accuracy: 0.9992
# Batch 1170/2000, Train Loss: 0.1137, Val Loss: 0.0932, Accuracy: 0.9992
# Batch 1175/2000, Train Loss: 0.1512, Val Loss: 0.0413, Accuracy: 0.9992
# Batch 1180/2000, Train Loss: 0.0418, Val Loss: 0.0386, Accuracy: 0.9992
# Batch 1185/2000, Train Loss: 0.1219, Val Loss: 0.1583, Accuracy: 0.9992
# Batch 1190/2000, Train Loss: 0.0991, Val Loss: 0.0425, Accuracy: 0.9992
# Batch 1195/2000, Train Loss: 0.0131, Val Loss: 0.0721, Accuracy: 0.9992
# Batch 1200/2000, Train Loss: 0.0443, Val Loss: 0.0254, Accuracy: 0.9992
# Batch 1205/2000, Train Loss: 0.1050, Val Loss: 0.1540, Accuracy: 0.9992
# Batch 1210/2000, Train Loss: 0.1018, Val Loss: 0.1474, Accuracy: 0.9992
# Batch 1215/2000, Train Loss: 0.0290, Val Loss: 0.0930, Accuracy: 0.9992
# Batch 1220/2000, Train Loss: 0.1346, Val Loss: 0.1112, Accuracy: 0.9992
# Batch 1225/2000, Train Loss: 0.0681, Val Loss: 0.1001, Accuracy: 0.9992
# Batch 1230/2000, Train Loss: 0.1722, Val Loss: 0.2370, Accuracy: 0.9992
# Batch 1235/2000, Train Loss: 0.1939, Val Loss: 0.0131, Accuracy: 0.9992
# Batch 1240/2000, Train Loss: 0.1021, Val Loss: 0.0622, Accuracy: 0.9992
# Batch 1245/2000, Train Loss: 0.0957, Val Loss: 0.1644, Accuracy: 0.9992
# Batch 1250/2000, Train Loss: 0.0574, Val Loss: 0.1056, Accuracy: 0.9992
# Batch 1255/2000, Train Loss: 0.0851, Val Loss: 0.0348, Accuracy: 0.9992
# Batch 1260/2000, Train Loss: 0.0507, Val Loss: 0.1373, Accuracy: 0.9992
# Batch 1265/2000, Train Loss: 0.1208, Val Loss: 0.0267, Accuracy: 0.9992
# Batch 1270/2000, Train Loss: 0.1189, Val Loss: 0.0962, Accuracy: 0.9992
# Batch 1275/2000, Train Loss: 0.2053, Val Loss: 0.1099, Accuracy: 0.9992
# Batch 1280/2000, Train Loss: 0.1275, Val Loss: 0.0443, Accuracy: 0.9992
# Batch 1285/2000, Train Loss: 0.1002, Val Loss: 0.0637, Accuracy: 0.9992
# Batch 1290/2000, Train Loss: 0.0952, Val Loss: 0.0761, Accuracy: 0.9992
# Batch 1295/2000, Train Loss: 0.1437, Val Loss: 0.0237, Accuracy: 0.9992
# Batch 1300/2000, Train Loss: 0.0469, Val Loss: 0.0504, Accuracy: 0.9992
# Batch 1305/2000, Train Loss: 0.1848, Val Loss: 0.0319, Accuracy: 0.9992
# Batch 1310/2000, Train Loss: 0.0351, Val Loss: 0.1117, Accuracy: 0.9992
# Batch 1315/2000, Train Loss: 0.0487, Val Loss: 0.2104, Accuracy: 0.9992
# Batch 1320/2000, Train Loss: 0.1378, Val Loss: 0.0126, Accuracy: 0.9992
# Batch 1325/2000, Train Loss: 0.0971, Val Loss: 0.0677, Accuracy: 0.9992
# Batch 1330/2000, Train Loss: 0.0553, Val Loss: 0.1174, Accuracy: 0.9992
# Batch 1335/2000, Train Loss: 0.1275, Val Loss: 0.1287, Accuracy: 0.9992
# Batch 1340/2000, Train Loss: 0.1329, Val Loss: 0.1003, Accuracy: 0.9992
# Batch 1345/2000, Train Loss: 0.1057, Val Loss: 0.1147, Accuracy: 0.9992
# Batch 1350/2000, Train Loss: 0.0506, Val Loss: 0.2231, Accuracy: 0.9992
# Batch 1355/2000, Train Loss: 0.0144, Val Loss: 0.1690, Accuracy: 0.9992
# Batch 1360/2000, Train Loss: 0.1871, Val Loss: 0.0483, Accuracy: 0.9992
# Batch 1365/2000, Train Loss: 0.0943, Val Loss: 0.1693, Accuracy: 0.9992
# Batch 1370/2000, Train Loss: 0.0195, Val Loss: 0.1222, Accuracy: 0.9992
# Batch 1375/2000, Train Loss: 0.1591, Val Loss: 0.0752, Accuracy: 0.9992
# Batch 1380/2000, Train Loss: 0.0612, Val Loss: 0.1391, Accuracy: 0.9992
# Batch 1385/2000, Train Loss: 0.1194, Val Loss: 0.0707, Accuracy: 0.9992
# Batch 1390/2000, Train Loss: 0.1369, Val Loss: 0.0442, Accuracy: 0.9992
# Batch 1395/2000, Train Loss: 0.2395, Val Loss: 0.0122, Accuracy: 0.9992
# Batch 1400/2000, Train Loss: 0.1282, Val Loss: 0.1916, Accuracy: 0.9992
# Batch 1405/2000, Train Loss: 0.1575, Val Loss: 0.0139, Accuracy: 0.9992
# Batch 1410/2000, Train Loss: 0.1993, Val Loss: 0.0114, Accuracy: 0.9992
# Batch 1415/2000, Train Loss: 0.1160, Val Loss: 0.0477, Accuracy: 0.9992
# Batch 1420/2000, Train Loss: 0.1577, Val Loss: 0.0416, Accuracy: 0.9992
# Batch 1425/2000, Train Loss: 0.1308, Val Loss: 0.1920, Accuracy: 0.9992
# Batch 1430/2000, Train Loss: 0.0253, Val Loss: 0.1111, Accuracy: 0.9992
# Batch 1435/2000, Train Loss: 0.2472, Val Loss: 0.0393, Accuracy: 0.9992
# Batch 1440/2000, Train Loss: 0.1138, Val Loss: 0.0955, Accuracy: 0.9992
# Batch 1445/2000, Train Loss: 0.0734, Val Loss: 0.1690, Accuracy: 0.9992
# Batch 1450/2000, Train Loss: 0.0428, Val Loss: 0.0969, Accuracy: 0.9992
# Batch 1455/2000, Train Loss: 0.0734, Val Loss: 0.1249, Accuracy: 0.9992
# Batch 1460/2000, Train Loss: 0.1111, Val Loss: 0.2790, Accuracy: 0.9992
# Batch 1465/2000, Train Loss: 0.0258, Val Loss: 0.1736, Accuracy: 0.9992
# Batch 1470/2000, Train Loss: 0.1207, Val Loss: 0.1044, Accuracy: 0.9992
# Batch 1475/2000, Train Loss: 0.0320, Val Loss: 0.2250, Accuracy: 0.9992
# Batch 1480/2000, Train Loss: 0.1719, Val Loss: 0.0764, Accuracy: 0.9992
# Batch 1485/2000, Train Loss: 0.0718, Val Loss: 0.1719, Accuracy: 0.9992
# Batch 1490/2000, Train Loss: 0.0454, Val Loss: 0.1708, Accuracy: 0.9992
# Batch 1495/2000, Train Loss: 0.0886, Val Loss: 0.1107, Accuracy: 0.9992
# Batch 1500/2000, Train Loss: 0.0745, Val Loss: 0.0924, Accuracy: 0.9992
# Batch 1505/2000, Train Loss: 0.1229, Val Loss: 0.0369, Accuracy: 0.9992
# Batch 1510/2000, Train Loss: 0.0236, Val Loss: 0.1185, Accuracy: 0.9992
# Batch 1515/2000, Train Loss: 0.0541, Val Loss: 0.0895, Accuracy: 0.9992
# Batch 1520/2000, Train Loss: 0.1196, Val Loss: 0.0198, Accuracy: 0.9992
# Batch 1525/2000, Train Loss: 0.1065, Val Loss: 0.0910, Accuracy: 0.9992
# Batch 1530/2000, Train Loss: 0.1934, Val Loss: 0.0325, Accuracy: 0.9992
# Batch 1535/2000, Train Loss: 0.0951, Val Loss: 0.0703, Accuracy: 0.9992
# Batch 1540/2000, Train Loss: 0.1816, Val Loss: 0.0150, Accuracy: 0.9992
# Batch 1545/2000, Train Loss: 0.0268, Val Loss: 0.0160, Accuracy: 0.9992
# Batch 1550/2000, Train Loss: 0.0373, Val Loss: 0.0482, Accuracy: 0.9992
# Batch 1555/2000, Train Loss: 0.1488, Val Loss: 0.0427, Accuracy: 0.9992
# Batch 1560/2000, Train Loss: 0.0164, Val Loss: 0.1099, Accuracy: 0.9992
# Batch 1565/2000, Train Loss: 0.1170, Val Loss: 0.0516, Accuracy: 0.9992
# Batch 1570/2000, Train Loss: 0.0873, Val Loss: 0.1979, Accuracy: 0.9992
# Batch 1575/2000, Train Loss: 0.0975, Val Loss: 0.0975, Accuracy: 0.9992
# Batch 1580/2000, Train Loss: 0.1792, Val Loss: 0.0633, Accuracy: 0.9992
# Batch 1585/2000, Train Loss: 0.1292, Val Loss: 0.0325, Accuracy: 0.9992
# Batch 1590/2000, Train Loss: 0.1002, Val Loss: 0.0406, Accuracy: 0.9992
# Batch 1595/2000, Train Loss: 0.1022, Val Loss: 0.0923, Accuracy: 0.9992
# Batch 1600/2000, Train Loss: 0.1822, Val Loss: 0.0144, Accuracy: 0.9992
# Batch 1605/2000, Train Loss: 0.2287, Val Loss: 0.0190, Accuracy: 0.9992
# Batch 1610/2000, Train Loss: 0.0139, Val Loss: 0.0306, Accuracy: 0.9992
# Batch 1615/2000, Train Loss: 0.0575, Val Loss: 0.1578, Accuracy: 0.9992
# Batch 1620/2000, Train Loss: 0.0853, Val Loss: 0.0289, Accuracy: 0.9992
# Batch 1625/2000, Train Loss: 0.0642, Val Loss: 0.1119, Accuracy: 0.9992
# Batch 1630/2000, Train Loss: 0.2672, Val Loss: 0.0393, Accuracy: 0.9992
# Batch 1635/2000, Train Loss: 0.1857, Val Loss: 0.0547, Accuracy: 0.9992
# Batch 1640/2000, Train Loss: 0.1124, Val Loss: 0.0229, Accuracy: 0.9992
# Batch 1645/2000, Train Loss: 0.1320, Val Loss: 0.0743, Accuracy: 0.9992
# Batch 1650/2000, Train Loss: 0.0538, Val Loss: 0.0759, Accuracy: 0.9992
# Batch 1655/2000, Train Loss: 0.1158, Val Loss: 0.1745, Accuracy: 0.9992
# Batch 1660/2000, Train Loss: 0.1192, Val Loss: 0.0927, Accuracy: 0.9992
# Batch 1665/2000, Train Loss: 0.0974, Val Loss: 0.1535, Accuracy: 0.9992
# Batch 1670/2000, Train Loss: 0.0929, Val Loss: 0.0973, Accuracy: 0.9992
# Batch 1675/2000, Train Loss: 0.0225, Val Loss: 0.1221, Accuracy: 0.9992
# Batch 1680/2000, Train Loss: 0.0388, Val Loss: 0.1355, Accuracy: 0.9992
# Batch 1685/2000, Train Loss: 0.0258, Val Loss: 0.0711, Accuracy: 0.9992
# Batch 1690/2000, Train Loss: 0.0362, Val Loss: 0.1744, Accuracy: 0.9992
# Batch 1695/2000, Train Loss: 0.0955, Val Loss: 0.0540, Accuracy: 0.9992
# Batch 1700/2000, Train Loss: 0.0830, Val Loss: 0.3018, Accuracy: 0.9992
# Batch 1705/2000, Train Loss: 0.1353, Val Loss: 0.0943, Accuracy: 0.9992
# Batch 1710/2000, Train Loss: 0.1265, Val Loss: 0.1016, Accuracy: 0.9992
# Batch 1715/2000, Train Loss: 0.0767, Val Loss: 0.1168, Accuracy: 0.9992
# Batch 1720/2000, Train Loss: 0.0820, Val Loss: 0.1194, Accuracy: 0.9992
# Batch 1725/2000, Train Loss: 0.1267, Val Loss: 0.0406, Accuracy: 0.9992
# Batch 1730/2000, Train Loss: 0.0583, Val Loss: 0.2340, Accuracy: 0.9992
# Batch 1735/2000, Train Loss: 0.1078, Val Loss: 0.1247, Accuracy: 0.9992
# Batch 1740/2000, Train Loss: 0.1844, Val Loss: 0.0344, Accuracy: 0.9992
# Batch 1745/2000, Train Loss: 0.0464, Val Loss: 0.0746, Accuracy: 0.9992
# Batch 1750/2000, Train Loss: 0.0948, Val Loss: 0.0547, Accuracy: 0.9992
# Batch 1755/2000, Train Loss: 0.0367, Val Loss: 0.0217, Accuracy: 0.9992
# Batch 1760/2000, Train Loss: 0.1659, Val Loss: 0.0274, Accuracy: 0.9992
# Batch 1765/2000, Train Loss: 0.1699, Val Loss: 0.0472, Accuracy: 0.9992
# Batch 1770/2000, Train Loss: 0.0823, Val Loss: 0.1051, Accuracy: 0.9992
# Batch 1775/2000, Train Loss: 0.1259, Val Loss: 0.0282, Accuracy: 0.9992
# Batch 1780/2000, Train Loss: 0.1124, Val Loss: 0.0325, Accuracy: 0.9992
# Batch 1785/2000, Train Loss: 0.0430, Val Loss: 0.0638, Accuracy: 0.9992
# Batch 1790/2000, Train Loss: 0.0238, Val Loss: 0.1074, Accuracy: 0.9992
# Batch 1795/2000, Train Loss: 0.1471, Val Loss: 0.1680, Accuracy: 0.9992
# Batch 1800/2000, Train Loss: 0.0975, Val Loss: 0.1235, Accuracy: 0.9992
# Batch 1805/2000, Train Loss: 0.0788, Val Loss: 0.1440, Accuracy: 0.9992
# Batch 1810/2000, Train Loss: 0.1547, Val Loss: 0.0431, Accuracy: 0.9992
# Batch 1815/2000, Train Loss: 0.0870, Val Loss: 0.1311, Accuracy: 0.9992
# Batch 1820/2000, Train Loss: 0.1322, Val Loss: 0.0621, Accuracy: 0.9992
# Batch 1825/2000, Train Loss: 0.1654, Val Loss: 0.1640, Accuracy: 0.9992
# Batch 1830/2000, Train Loss: 0.0945, Val Loss: 0.1091, Accuracy: 0.9992
# Batch 1835/2000, Train Loss: 0.2316, Val Loss: 0.0686, Accuracy: 0.9992
# Batch 1840/2000, Train Loss: 0.0856, Val Loss: 0.1397, Accuracy: 0.9992
# Batch 1845/2000, Train Loss: 0.0160, Val Loss: 0.0468, Accuracy: 0.9992
# Batch 1850/2000, Train Loss: 0.2219, Val Loss: 0.0741, Accuracy: 0.9992
# Batch 1855/2000, Train Loss: 0.2258, Val Loss: 0.1308, Accuracy: 0.9992
# Batch 1860/2000, Train Loss: 0.0368, Val Loss: 0.2180, Accuracy: 0.9992
# Batch 1865/2000, Train Loss: 0.0283, Val Loss: 0.0377, Accuracy: 0.9992
# Batch 1870/2000, Train Loss: 0.1586, Val Loss: 0.0887, Accuracy: 0.9992
# Batch 1875/2000, Train Loss: 0.1172, Val Loss: 0.1333, Accuracy: 0.9992
# Batch 1880/2000, Train Loss: 0.1402, Val Loss: 0.0804, Accuracy: 0.9992
# Batch 1885/2000, Train Loss: 0.0603, Val Loss: 0.0320, Accuracy: 0.9992
# Batch 1890/2000, Train Loss: 0.0183, Val Loss: 0.0874, Accuracy: 0.9992
# Batch 1895/2000, Train Loss: 0.0673, Val Loss: 0.0213, Accuracy: 0.9992
# Batch 1900/2000, Train Loss: 0.1574, Val Loss: 0.2658, Accuracy: 0.9992
# Batch 1905/2000, Train Loss: 0.1334, Val Loss: 0.0658, Accuracy: 0.9992
# Batch 1910/2000, Train Loss: 0.0340, Val Loss: 0.1131, Accuracy: 0.9992
# Batch 1915/2000, Train Loss: 0.0932, Val Loss: 0.0305, Accuracy: 0.9992
# Batch 1920/2000, Train Loss: 0.2113, Val Loss: 0.1801, Accuracy: 0.9992
# Batch 1925/2000, Train Loss: 0.0635, Val Loss: 0.1455, Accuracy: 0.9992
# Batch 1930/2000, Train Loss: 0.0337, Val Loss: 0.1179, Accuracy: 0.9992
# Batch 1935/2000, Train Loss: 0.0660, Val Loss: 0.0923, Accuracy: 0.9992
# Batch 1940/2000, Train Loss: 0.1726, Val Loss: 0.1269, Accuracy: 0.9992
# Batch 1945/2000, Train Loss: 0.0226, Val Loss: 0.1780, Accuracy: 0.9992
# Batch 1950/2000, Train Loss: 0.0711, Val Loss: 0.1052, Accuracy: 0.9992
# Batch 1955/2000, Train Loss: 0.0345, Val Loss: 0.0902, Accuracy: 0.9992
# Batch 1960/2000, Train Loss: 0.1391, Val Loss: 0.0465, Accuracy: 0.9992
# Batch 1965/2000, Train Loss: 0.1397, Val Loss: 0.0916, Accuracy: 0.9992
# Batch 1970/2000, Train Loss: 0.0662, Val Loss: 0.1784, Accuracy: 0.9992
# Batch 1975/2000, Train Loss: 0.2414, Val Loss: 0.0974, Accuracy: 0.9992
# Batch 1980/2000, Train Loss: 0.0327, Val Loss: 0.0200, Accuracy: 0.9992
# Batch 1985/2000, Train Loss: 0.0316, Val Loss: 0.0233, Accuracy: 0.9992
# Batch 1990/2000, Train Loss: 0.0560, Val Loss: 0.1108, Accuracy: 0.9992
# Batch 1995/2000, Train Loss: 0.0867, Val Loss: 0.1335, Accuracy: 0.9992
# Batch 2000/2000, Train Loss: 0.1098, Val Loss: 0.1247, Accuracy: 0.9988
# Model saved at epoch 50, file: c:\Users\jaime\ML_Playground_1\LifeGPT\Multi_Grid\model_parameters\01_07_2025_Conway_Multi_Grid_2025-01-08_13-09-21\LifeGPT_multi_grid_epoch_50.pt
# Epoch 50 time: 461.79 seconds

# %%
data_path = "datasets\\"
train_file = data_path + "conway_multi_grid_train_20250107_180038.csv"
val_file   = data_path + "conway_multi_grid_val_20250107_181530.csv"
test_file  = data_path + "conway_multi_grid_test_20250107_181732.csv"

df_train = pd.read_csv(train_file)
df_val   = pd.read_csv(val_file)
df_test  = pd.read_csv(test_file)

# %%
def check_duplicates():
    # Assuming both dataframes have the same structure, we'll check State 1 column for duplicates
    duplicates = []
    
    # Iterate through test dataset
    for test_idx, test_row in df_test.iterrows():
        # Find matching rows in train dataset
        train_matches = df_train[df_train['State 1'] == test_row['State 1']]
        
        if not train_matches.empty:
            for train_idx in train_matches.index:
                # Deep comparison of all relevant state columns
                all_states_match = True
                for col in [col for col in df_test.columns if col.startswith('State')]:
                    if df_test.loc[test_idx, col] != df_train.loc[train_idx, col]:
                        all_states_match = False
                        break
                
                if all_states_match:
                    duplicates.append({
                        'test_row': test_idx,
                        'train_row': train_idx,
                        'state_1': test_row['State 1']
                    })
    
    if duplicates:
        print(f"Found {len(duplicates)} duplicate samples:")
        for dup in duplicates:
            print(f"Test row {dup['test_row']} matches Train row {dup['train_row']}")
    else:
        print("No duplicates found between test and train datasets")

# Run the check
check_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 34
#      31         print("No duplicates found between test and train datasets")
#      33 # Run the check
# ---> 34 check_duplicates()
#
# Cell In[1], line 6, in check_duplicates()
#       3 duplicates = []
#       5 # Iterate through test dataset
# ----> 6 for test_idx, test_row in df_test.iterrows():
#       7     # Find matching rows in train dataset
#       8     train_matches = df_train[df_train['State 1'] == test_row['State 1']]
#      10     if not train_matches.empty:
#
# NameError: name 'df_test' is not defined
